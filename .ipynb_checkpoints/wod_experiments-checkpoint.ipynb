# %%
from wodparser import wodparser
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %%
dates = pd.date_range(start='1/1/2009', end='3/8/2020')
wp = wodparser.WodParser(dates)
# Out:
# Parsing 29.4%
# Something did not work for 2012/04/14
# Parsing 50.8%
# Something did not work for 2014/09/07
# Parsing 69.6%
# Something did not work for 2016/10/14
# Parsing 89.3%
# Something did not work for 2018/12/27
# Parsing 89.4%
# Something did not work for 2018/12/31
# Parsing 92.0%
# Something did not work for 2019/04/17
# Parsing 100.0%

# %%
print("Number of WODs: %d" % len(wp.wods))
print("Number of movements: %d" % wp.df.shape[0])
# Out:
# Number of WODs: 3020
# Number of movements: 61

# %% [markdown]
# In total there are 2921 WODs that were parsed successfully from crossfit.com. I know there are some more (you can see that for some dates there were problems parsing the data, but as it's only a few days I'll stick with that. Actually if you take the time to look at those dates in question, a few are rest days anyways).
#
# In these almost 3000 WODs 63 different movements were used.

# %% [markdown]
# The Top10 movements are the following:

# %%
wp.df.head(10)
# Out:
#           Movement  Counts  Percentage
# 0           pullup     650   21.523179
# 1              run     552   18.278146
# 2         deadlift     370   12.251656
# 3              row     350   11.589404
# 4         thruster     249    8.245033
# 5           pushup     245    8.112583
# 6           burpee     239    7.913907
# 7            squat     230    7.615894
# 8  handstandpushup     212    7.019868
# 9         muscleup     204    6.754967

# %%
wp.df.Percentage.sum()
# Out:
# 229.7682119205298

# %%
wp.plot()

# %%
wp.df.plot.bar(x='Movement', y='Percentage', figsize=(15,7.5), color='#9c0015',  edgecolor='black')

# %%
for k in wp.wods_raw.keys():
    if 'burpee' in wp.wods_raw[k]:
        print(wp.wods_raw[k])
# Out:
# For time:
# 100 Inverted burpeesPost time to comments.
# 6 rounds for time of:
# Run 400 meters
# 25 BurpeesSet up under a bar that is one foot above your reach for the burpees. Jump and touch the bar for each burpee rep.
# 6 rounds for time of:
# Run 400 meters
# 25 BurpeesSet up under a bar that is one foot above your reach for the burpees. Jump and touch the bar for each burpee rep.
# Complete as many rounds as possible in 20 minutes of:
# 185 pound Back squat, 7 reps
# 45 pound dumbbell Overhead walking lunge, 10 steps (right hand)
# 7 Burpees
# ...

# %%
'burpee' in wp.df.Movement.values
# Out:
# False

# %%
edge_counter = Counter()
for e in edges:
    edge_counter[e] +=1
    
edge_counter.most_common()
# Out:
# [(('pullup', 'run'), 119),
#  (('run', 'pullup'), 119),
#  (('pullup', 'pushup'), 117),
#  (('pushup', 'pullup'), 117),
#  (('squat', 'pushup'), 103),
#  (('pushup', 'squat'), 103),
#  (('squat', 'pullup'), 100),
#  (('pullup', 'squat'), 100),
#  (('pullup', 'thruster'), 80),
#  (('thruster', 'pullup'), 80),
#  (('wallball', 'boxjump'), 77),
#  (('boxjump', 'wallball'), 77),
#  (('pullup', 'burpee'), 73),
#  (('burpee', 'pullup'), 73),
#  (('pullup', 'situp'), 65),
#  (('situp', 'pullup'), 65),
#  (('pullup', 'kettlebellswing'), 62),
#  (('kettlebellswing', 'pullup'), 62),
#  (('pullup', 'handstandpushup'), 60),
#  (('handstandpushup', 'pullup'), 60),
#  (('pullup', 'boxjump'), 56),
#  (('boxjump', 'pullup'), 56),
#  (('boxjump', 'burpee'), 52),
#  (('burpee', 'boxjump'), 52),
#  (('pullup', 'row'), 49),
#  (('pushup', 'situp'), 49),
#  (('situp', 'pushup'), 49),
#  (('row', 'pullup'), 49),
#  (('pullup', 'wallball'), 47),
#  (('wallball', 'pullup'), 47),
#  (('run', 'burpee'), 46),
# ...

# %%
for e in G.edges:
#     if (e[0] == 'thruster') & (e[1] == 'wallball'):
    print(e[0], e[1])
# Out:
# squat pullup
# squat pushup
# squat situp
# squat muscleup
# squat run
# squat benchpress
# squat overheadsquat
# squat handstandpushup
# squat row
# squat ghdsitup
# squat ropeclimb
# squat dip
# squat snatch
# squat backextension
# squat walkinglunge
# squat pushpress
# squat deadlift
# squat handstandwalk
# squat kettlebellswing
# squat toestobar
# squat backsquat
# squat doubleunder
# squat sprint
# squat burpee
# squat lunge
# squat wallball
# squat kneestoelbow
# squat swim
# squat pushjerk
# squat snatchbalance
# squat boxjump
# squat thruster
# squat hipextension
# squat squatclean
# squat bike
# squat frontsquat
# pullup pushup
# pullup situp
# pullup wallball
# pullup thruster
# pullup benchpress
# pullup run
# pullup burpee
# pullup deadlift
# pullup handstandpushup
# pullup pushjerk
# pullup boxjump
# pullup walkinglunge
# pullup pushpress
# pullup muscleup
# pullup doubleunder
# pullup squatclean
# pullup toestobar
# pullup row
# pullup ghdsitup
# pullup frontsquat
# ...
