# %%
from wodparser import wodparser
from bs4 import BeautifulSoup
import requests

import pandas as pd
import sys
import re

# %% [markdown]
# # Test Area

# %%
url = r'https://www.crossfit.com/workout/2018/10'
url = r'https://www.crossfit.com/workout/2010/02/02'

r  = requests.get(url)
data = r.text

# with open(url) as fp:
soup = BeautifulSoup(data)

x = soup.find_all('div', {"class":'content'})

a = []
wod = x[0]
for i in wod.select('p'):
    a.append(i.get_text())
    
wod.select('p')[0].get_text() + wod.select('p')[1].get_text()
# Out:
# '"Griff"For time:\nRun 800 meters\nRun 400 meters backwards\nRun 800 meters\nRun 400 meters backwards'

# %%
# Out:
# <p>Five rounds, each for time of:<br/>
# 20 Pull-ups<br/>
# 30 Push-ups<br/>
# 40 Sit-ups<br/>
# 50 Squats</p>

# %%
u = x[0]
u.select_all('p')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-2f7f0a6fdfcd> in <module>
#       1 u = x[0]
# ----> 2 u.select_all('p')
#
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# # Get Wods

# %%
dates = pd.date_range(start='1/1/2010', end='10/27/2019')

# %%
def get_wods(dates):
    wods = {}
    n_dates = len(dates)
    for i, da in enumerate(dates):
        url = r'https://www.crossfit.com/workout/%s' % da.strftime('%Y/%m/%d')
        
        r  = requests.get(url)
        data = r.text
        soup = BeautifulSoup(data)
        x = soup.find_all('div', {"class":'content'})
        try:
            wod = x[0].select('p')[0].get_text() + x[0].select('p')[1].get_text()
            if x[0].select('p')[0].get_text() != 'Rest Day':       
                wods[da.strftime('%Y/%m/%d')] = wod
        except:
            print('Something did not work for %s' % da.strftime('%Y/%m/%d'))
        
        sys.stdout.write("\rParsing %4.1f%%" % ((i+1)/n_dates * 100))
    
    return wods
        
wods_raw = get_wods(dates)
# Out:
# Parsing 23.3%Something did not work for 2012/04/14
# Parsing 47.7%Something did not work for 2014/09/07
# Parsing 69.1%Something did not work for 2016/10/14
# Parsing 91.5%Something did not work for 2018/12/27
# Parsing 91.6%Something did not work for 2018/12/31
# Parsing 91.6%Something did not work for 2019/01/01
# Parsing 91.7%Something did not work for 2019/01/02
# Parsing 91.7%Something did not work for 2019/01/03
# Parsing 91.7%Something did not work for 2019/01/04
# Parsing 91.7%Something did not work for 2019/01/05
# Parsing 91.8%Something did not work for 2019/01/06
# Parsing 91.8%Something did not work for 2019/01/07
# Parsing 91.8%Something did not work for 2019/01/08
# Parsing 91.9%Something did not work for 2019/01/09
# Parsing 91.9%Something did not work for 2019/01/10
# Parsing 91.9%Something did not work for 2019/01/11
# Parsing 91.9%Something did not work for 2019/01/12
# Parsing 92.0%Something did not work for 2019/01/13
# Parsing 92.0%Something did not work for 2019/01/14
# Parsing 92.0%Something did not work for 2019/01/15
# Parsing 92.1%Something did not work for 2019/01/16
# Parsing 92.1%Something did not work for 2019/01/17
# Parsing 92.1%Something did not work for 2019/01/18
# Parsing 92.1%Something did not work for 2019/01/19
# Parsing 92.2%Something did not work for 2019/01/20
# Parsing 92.2%Something did not work for 2019/01/21
# Parsing 92.2%Something did not work for 2019/01/22
# Parsing 92.2%Something did not work for 2019/01/23
# Parsing 92.3%Something did not work for 2019/01/24
# Parsing 92.3%Something did not work for 2019/01/25
# Parsing 92.3%Something did not work for 2019/01/26
# Parsing 92.4%Something did not work for 2019/01/27
# Parsing 92.4%Something did not work for 2019/01/28
# Parsing 92.4%Something did not work for 2019/01/29
# Parsing 92.4%Something did not work for 2019/01/30
# Parsing 92.5%Something did not work for 2019/01/31
# Parsing 92.5%Something did not work for 2019/02/01
# Parsing 92.5%Something did not work for 2019/02/02
# Parsing 92.6%Something did not work for 2019/02/03
# Parsing 92.6%Something did not work for 2019/02/04
# Parsing 92.6%Something did not work for 2019/02/05
# Parsing 92.6%Something did not work for 2019/02/06
# Parsing 92.7%Something did not work for 2019/02/07
# Parsing 92.7%Something did not work for 2019/02/08
# Parsing 92.7%Something did not work for 2019/02/09
# Parsing 92.8%Something did not work for 2019/02/10
# Parsing 92.8%Something did not work for 2019/02/11
# Parsing 92.8%Something did not work for 2019/02/12
# Parsing 92.8%Something did not work for 2019/02/13
# Parsing 92.9%Something did not work for 2019/02/14
# Parsing 92.9%Something did not work for 2019/02/15
# Parsing 92.9%Something did not work for 2019/02/16
# Parsing 92.9%Something did not work for 2019/02/17
# Parsing 93.0%Something did not work for 2019/02/18
# Parsing 93.0%Something did not work for 2019/02/19
# Parsing 93.0%Something did not work for 2019/02/20
# Parsing 93.1%Something did not work for 2019/02/21
# Parsing 93.1%Something did not work for 2019/02/22
# Parsing 93.1%Something did not work for 2019/02/23
# Parsing 93.1%Something did not work for 2019/02/24
# Parsing 93.2%Something did not work for 2019/02/25
# Parsing 93.2%Something did not work for 2019/02/26
# Parsing 93.2%Something did not work for 2019/02/27
# Parsing 93.3%Something did not work for 2019/02/28
# Parsing 93.3%Something did not work for 2019/03/01
# Parsing 93.3%Something did not work for 2019/03/02
# Parsing 93.3%Something did not work for 2019/03/03
# Parsing 93.4%Something did not work for 2019/03/04
# Parsing 93.4%Something did not work for 2019/03/05
# Parsing 93.4%Something did not work for 2019/03/06
# Parsing 93.4%Something did not work for 2019/03/07
# Parsing 93.5%Something did not work for 2019/03/08
# Parsing 93.5%Something did not work for 2019/03/09
# Parsing 93.5%Something did not work for 2019/03/10
# Parsing 93.6%Something did not work for 2019/03/11
# Parsing 93.6%Something did not work for 2019/03/12
# Parsing 93.6%Something did not work for 2019/03/13
# Parsing 93.6%Something did not work for 2019/03/14
# Parsing 93.7%Something did not work for 2019/03/15
# Parsing 93.7%Something did not work for 2019/03/16
# Parsing 93.7%Something did not work for 2019/03/17
# Parsing 93.8%Something did not work for 2019/03/18
# Parsing 93.8%Something did not work for 2019/03/19
# Parsing 93.8%Something did not work for 2019/03/20
# Parsing 93.8%Something did not work for 2019/03/21
# Parsing 93.9%Something did not work for 2019/03/22
# Parsing 93.9%Something did not work for 2019/03/23
# Parsing 93.9%Something did not work for 2019/03/24
# Parsing 94.0%Something did not work for 2019/03/25
# Parsing 94.0%Something did not work for 2019/03/26
# Parsing 94.0%Something did not work for 2019/03/27
# Parsing 94.0%Something did not work for 2019/03/28
# Parsing 94.1%Something did not work for 2019/03/29
# Parsing 94.1%Something did not work for 2019/03/30
# Parsing 94.1%Something did not work for 2019/03/31
# Parsing 94.1%Something did not work for 2019/04/01
# Parsing 94.2%Something did not work for 2019/04/02
# Parsing 94.2%Something did not work for 2019/04/03
# Parsing 94.2%Something did not work for 2019/04/04
# Parsing 94.3%Something did not work for 2019/04/05
# Parsing 94.3%Something did not work for 2019/04/06
# Parsing 94.3%Something did not work for 2019/04/07
# Parsing 94.3%Something did not work for 2019/04/08
# Parsing 94.4%Something did not work for 2019/04/09
# Parsing 94.4%Something did not work for 2019/04/10
# Parsing 94.4%Something did not work for 2019/04/11
# Parsing 94.5%Something did not work for 2019/04/12
# Parsing 94.5%Something did not work for 2019/04/13
# Parsing 94.5%Something did not work for 2019/04/14
# Parsing 94.5%Something did not work for 2019/04/15
# Parsing 94.6%Something did not work for 2019/04/16
# Parsing 94.6%Something did not work for 2019/04/17
# Parsing 94.6%Something did not work for 2019/04/18
# Parsing 94.6%Something did not work for 2019/04/19
# Parsing 94.7%Something did not work for 2019/04/20
# Parsing 94.7%Something did not work for 2019/04/21
# Parsing 94.7%Something did not work for 2019/04/22
# Parsing 94.8%Something did not work for 2019/04/23
# Parsing 94.8%Something did not work for 2019/04/24
# Parsing 94.8%Something did not work for 2019/04/25
# Parsing 94.8%Something did not work for 2019/04/26
# Parsing 94.9%Something did not work for 2019/04/27
# Parsing 94.9%Something did not work for 2019/04/28
# Parsing 94.9%Something did not work for 2019/04/29
# Parsing 95.0%Something did not work for 2019/04/30
# Parsing 95.0%Something did not work for 2019/05/01
# Parsing 95.0%Something did not work for 2019/05/02
# Parsing 95.0%Something did not work for 2019/05/03
# Parsing 95.1%Something did not work for 2019/05/04
# Parsing 95.1%Something did not work for 2019/05/05
# Parsing 95.1%Something did not work for 2019/05/06
# Parsing 95.1%Something did not work for 2019/05/07
# Parsing 95.2%Something did not work for 2019/05/08
# Parsing 95.2%Something did not work for 2019/05/09
# Parsing 95.2%Something did not work for 2019/05/10
# Parsing 95.3%Something did not work for 2019/05/11
# Parsing 95.3%Something did not work for 2019/05/12
# Parsing 95.3%Something did not work for 2019/05/13
# Parsing 95.3%Something did not work for 2019/05/14
# Parsing 95.4%Something did not work for 2019/05/15
# Parsing 95.4%Something did not work for 2019/05/16
# Parsing 95.4%Something did not work for 2019/05/17
# Parsing 95.5%Something did not work for 2019/05/18
# Parsing 95.5%Something did not work for 2019/05/19
# Parsing 95.5%Something did not work for 2019/05/20
# Parsing 95.5%Something did not work for 2019/05/21
# Parsing 95.6%Something did not work for 2019/05/22
# Parsing 95.6%Something did not work for 2019/05/23
# Parsing 95.6%Something did not work for 2019/05/24
# Parsing 95.7%Something did not work for 2019/05/25
# Parsing 95.7%Something did not work for 2019/05/26
# Parsing 95.7%Something did not work for 2019/05/27
# Parsing 95.7%Something did not work for 2019/05/28
# Parsing 95.8%Something did not work for 2019/05/29
# Parsing 95.8%Something did not work for 2019/05/30
# Parsing 95.8%Something did not work for 2019/05/31
# Parsing 95.8%Something did not work for 2019/06/01
# Parsing 95.9%Something did not work for 2019/06/02
# Parsing 95.9%Something did not work for 2019/06/03
# Parsing 95.9%Something did not work for 2019/06/04
# Parsing 96.0%Something did not work for 2019/06/05
# Parsing 96.0%Something did not work for 2019/06/06
# Parsing 96.0%Something did not work for 2019/06/07
# Parsing 96.0%Something did not work for 2019/06/08
# Parsing 96.1%Something did not work for 2019/06/09
# Parsing 96.1%Something did not work for 2019/06/10
# Parsing 96.1%Something did not work for 2019/06/11
# Parsing 96.2%Something did not work for 2019/06/12
# Parsing 96.2%Something did not work for 2019/06/13
# Parsing 96.2%Something did not work for 2019/06/14
# Parsing 96.2%Something did not work for 2019/06/15
# Parsing 96.3%Something did not work for 2019/06/16
# Parsing 96.3%Something did not work for 2019/06/17
# Parsing 96.3%Something did not work for 2019/06/18
# Parsing 96.3%Something did not work for 2019/06/19
# Parsing 96.4%Something did not work for 2019/06/20
# Parsing 96.4%Something did not work for 2019/06/21
# Parsing 96.4%Something did not work for 2019/06/22
# Parsing 96.5%Something did not work for 2019/06/23
# Parsing 96.5%Something did not work for 2019/06/24
# Parsing 96.5%Something did not work for 2019/06/25
# Parsing 96.5%Something did not work for 2019/06/26
# Parsing 96.6%Something did not work for 2019/06/27
# Parsing 96.6%Something did not work for 2019/06/28
# Parsing 96.6%Something did not work for 2019/06/29
# Parsing 96.7%Something did not work for 2019/06/30
# Parsing 96.7%Something did not work for 2019/07/01
# Parsing 96.7%Something did not work for 2019/07/02
# Parsing 96.7%Something did not work for 2019/07/03
# Parsing 96.8%Something did not work for 2019/07/04
# Parsing 96.8%Something did not work for 2019/07/05
# Parsing 96.8%Something did not work for 2019/07/06
# Parsing 96.8%Something did not work for 2019/07/07
# Parsing 96.9%Something did not work for 2019/07/08
# Parsing 96.9%Something did not work for 2019/07/09
# Parsing 96.9%Something did not work for 2019/07/10
# Parsing 97.0%Something did not work for 2019/07/11
# Parsing 97.0%Something did not work for 2019/07/12
# Parsing 97.0%Something did not work for 2019/07/13
# Parsing 97.0%Something did not work for 2019/07/14
# Parsing 97.1%Something did not work for 2019/07/15
# Parsing 97.1%Something did not work for 2019/07/16
# Parsing 97.1%Something did not work for 2019/07/17
# Parsing 97.2%Something did not work for 2019/07/18
# Parsing 97.2%Something did not work for 2019/07/19
# Parsing 97.2%Something did not work for 2019/07/20
# Parsing 97.2%Something did not work for 2019/07/21
# Parsing 97.3%Something did not work for 2019/07/22
# Parsing 97.3%Something did not work for 2019/07/23
# Parsing 97.3%Something did not work for 2019/07/24
# Parsing 97.4%Something did not work for 2019/07/25
# Parsing 97.4%Something did not work for 2019/07/26
# Parsing 97.4%Something did not work for 2019/07/27
# Parsing 97.4%Something did not work for 2019/07/28
# Parsing 97.5%Something did not work for 2019/07/29
# Parsing 97.5%Something did not work for 2019/07/30
# Parsing 97.5%Something did not work for 2019/07/31
# Parsing 97.5%Something did not work for 2019/08/01
# Parsing 97.6%Something did not work for 2019/08/02
# Parsing 97.6%Something did not work for 2019/08/03
# Parsing 97.6%Something did not work for 2019/08/04
# Parsing 97.7%Something did not work for 2019/08/05
# Parsing 97.7%Something did not work for 2019/08/06
# Parsing 97.7%Something did not work for 2019/08/07
# Parsing 97.7%Something did not work for 2019/08/08
# Parsing 97.8%Something did not work for 2019/08/09
# Parsing 97.8%Something did not work for 2019/08/10
# Parsing 97.8%Something did not work for 2019/08/11
# Parsing 97.9%Something did not work for 2019/08/12
# Parsing 97.9%Something did not work for 2019/08/13
# Parsing 97.9%Something did not work for 2019/08/14
# Parsing 97.9%Something did not work for 2019/08/15
# Parsing 98.0%Something did not work for 2019/08/16
# Parsing 98.0%Something did not work for 2019/08/17
# Parsing 98.0%Something did not work for 2019/08/18
# Parsing 98.0%Something did not work for 2019/08/19
# Parsing 98.1%Something did not work for 2019/08/20
# Parsing 98.1%Something did not work for 2019/08/21
# Parsing 98.1%Something did not work for 2019/08/22
# Parsing 98.2%Something did not work for 2019/08/23
# Parsing 98.2%Something did not work for 2019/08/24
# Parsing 98.2%Something did not work for 2019/08/25
# Parsing 98.2%Something did not work for 2019/08/26
# Parsing 98.3%Something did not work for 2019/08/27
# Parsing 98.3%Something did not work for 2019/08/28
# Parsing 98.3%Something did not work for 2019/08/29
# Parsing 98.4%Something did not work for 2019/08/30
# Parsing 98.4%Something did not work for 2019/08/31
# Parsing 98.4%Something did not work for 2019/09/01
# Parsing 98.4%Something did not work for 2019/09/02
# Parsing 98.5%Something did not work for 2019/09/03
# Parsing 98.5%Something did not work for 2019/09/04
# Parsing 98.5%Something did not work for 2019/09/05
# Parsing 98.6%Something did not work for 2019/09/06
# Parsing 98.6%Something did not work for 2019/09/07
# Parsing 98.6%Something did not work for 2019/09/08
# Parsing 98.6%Something did not work for 2019/09/09
# Parsing 98.7%Something did not work for 2019/09/10
# Parsing 98.7%Something did not work for 2019/09/11
# Parsing 98.7%Something did not work for 2019/09/12
# Parsing 98.7%Something did not work for 2019/09/13
# Parsing 98.8%Something did not work for 2019/09/14
# Parsing 98.8%Something did not work for 2019/09/15
# Parsing 98.8%Something did not work for 2019/09/16
# Parsing 98.9%Something did not work for 2019/09/17
# Parsing 98.9%Something did not work for 2019/09/18
# Parsing 98.9%Something did not work for 2019/09/19
# Parsing 98.9%Something did not work for 2019/09/20
# Parsing 99.0%Something did not work for 2019/09/21
# Parsing 99.0%Something did not work for 2019/09/22
# Parsing 99.0%Something did not work for 2019/09/23
# Parsing 99.1%Something did not work for 2019/09/24
# Parsing 99.1%Something did not work for 2019/09/25
# Parsing 99.1%Something did not work for 2019/09/26
# Parsing 99.1%Something did not work for 2019/09/27
# Parsing 99.2%Something did not work for 2019/09/28
# Parsing 99.2%Something did not work for 2019/09/29
# Parsing 99.2%Something did not work for 2019/09/30
# Parsing 99.2%Something did not work for 2019/10/01
# Parsing 99.3%Something did not work for 2019/10/02
# Parsing 99.3%Something did not work for 2019/10/03
# Parsing 99.3%Something did not work for 2019/10/04
# Parsing 99.4%Something did not work for 2019/10/05
# Parsing 99.4%Something did not work for 2019/10/06
# Parsing 99.4%Something did not work for 2019/10/07
# Parsing 99.4%Something did not work for 2019/10/08
# Parsing 99.5%Something did not work for 2019/10/09
# Parsing 99.5%Something did not work for 2019/10/10
# Parsing 99.5%Something did not work for 2019/10/11
# Parsing 99.6%Something did not work for 2019/10/12
# Parsing 99.6%Something did not work for 2019/10/13
# Parsing 99.6%Something did not work for 2019/10/14
# Parsing 99.6%Something did not work for 2019/10/15
# Parsing 99.7%Something did not work for 2019/10/16
# Parsing 99.7%Something did not work for 2019/10/17
# Parsing 99.7%Something did not work for 2019/10/18
# Parsing 99.7%Something did not work for 2019/10/19
# Parsing 99.8%Something did not work for 2019/10/20
# Parsing 99.8%Something did not work for 2019/10/21
# Parsing 99.8%Something did not work for 2019/10/22
# Parsing 99.9%Something did not work for 2019/10/23
# Parsing 99.9%Something did not work for 2019/10/24
# Parsing 99.9%Something did not work for 2019/10/25
# Parsing 99.9%Something did not work for 2019/10/26
# Parsing 100.0%Something did not work for 2019/10/27
# Parsing 100.0%

# %%
import json
with open('raw_wod_data.json', 'w') as f:
    json.dump(wods_raw, f)

# %%
# Out:
# '"Cindy"\nComplete as many rounds in 20 minutes as you can of:\n5 Pull-ups\n10 Push-ups\n15 Squats'

# %%
# wod_regex = '(pull|push|muscle|sit|handstand push)[-]?up[s]?|(front[\s]?|back[\s]?|overhead[\s]?)?squat[s]?|wall[\s]?ball[s]?'
wod_regex1 = '(pull|push|muscle|(ghd\s)?sit|handstand push)[-]?up|(front[\s]?|back[\s]?|overhead[\s]?|single(-|\s)leg[\s]?|one(-|\s)legged[\s]?)?squat(\sclean|\ssnatch)?|wall(-|[\s])?ball|(sumo\s)?dead[\s]?lift'
wod_regex2 = '|(shoulder|push|bench|sots|split)\s(press|jerk)|(hip|back)[\s]?extension|knee[s]?(-|\s)to(-|\s)elbow|sprint|rope\sclimb|dip|swim|bike|handstand\swalk|turkish\sget[-]?up|wall(-|\s)?walk|(kettlebell\sswing)'
wod_regex3 = '|(bent\sover(\sbarbell)?\s)?row|pistol|(power\s|dumbbell\s)?(clean|snatch(es)?)(\sbalance|(\sand\s|\s&\s)jerk)?|(box\s)?step(-|\s)up|(single|double|triple)[-]?under|(box\sjump)|thruster'
wod_regex4 = '|run|burpee|(walking\s)?lunge|(broad)[-]?jump|(toes(-|\s)to(-|\s)bar)'

wod_regex = wod_regex1+wod_regex2+wod_regex3+wod_regex4

wods_clean = {}

for w in wods_raw.keys():
    matches = re.finditer(wod_regex, wods_raw[w], re.MULTILINE | re.IGNORECASE)

    wod_movements = set()
    for matchNum, match in enumerate(matches, start=1):    
        wod_movements.add(match.group().lower())
    
    wod_movements = [mv.replace(' ', '').strip() for mv in wod_movements]
    wod_movements = [mv.replace('-', '').strip() for mv in wod_movements]
    wod_movements = [mv.replace('snatches', 'snatch') for mv in wod_movements]
    wod_movements = [mv.replace('bentoverbarbell', 'bentover') for mv in wod_movements]
    wod_movements = [mv.replace('singlelegsquat', 'pistols') for mv in wod_movements]
    wod_movements = [mv.replace('oneleggedsquat', 'pistols') for mv in wod_movements]
    wod_movements = [mv.replace('&', 'and') for mv in wod_movements]
    wods_clean[w] = wod_movements
#         print ("Match {matchNum} was found at {start}-{end}: {match}".format(matchNum = matchNum, start = match.start(), end = match.end(), match = match.group()))

# for i in wods_raw.keys():
#     if 'step' in wods_raw[i].lower():
#         print(i, wods_raw[i])
#         print()

# %%
wods_clean['2014/01/19']
# Out:
# ['thruster', 'ghdsitup', 'backextension', 'cleanandjerk']

# %%
wods_raw['2010/01/10']
# Out:
# 'Push Jerk 1-1-1-1-1-1-1 repsPost loads to comments.'

# %%
wods_clean['2010/02/15']
# Out:
# ['burpee',
#  'pushjerk',
#  'boxjump',
#  'walkinglunge',
#  'thruster',
#  'pullup',
#  'pushpress',
#  'muscleup',
#  'doubleunder',
#  'squatclean',
#  'toestobar']

# %%
# for w in wods_raw.keys():
#     if 'cal' in wods_raw[w].lower():
#         print(wods_raw[w])
#         print()

# %%
wods = []

for i in wods_clean.keys():
    if list(wods_clean[i]):
        wods.append(list(wods_clean[i]))

print(len(wods))
# Out:
# 2440

# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter

# %%
movement_counter = Counter()
for wod in wods:
    for movement in wod:
        movement_counter[movement] +=1

# %%
df = pd.DataFrame(movement_counter.most_common(), columns =['Movement', 'Counts'])
df['Percentage'] = df['Counts'] / len(wods) * 100
df
# Out:
#                 Movement  Counts  Percentage
# 0                 pullup     515   21.106557
# 1                    run     440   18.032787
# 2               deadlift     301   12.336066
# 3                    row     263   10.778689
# 4                 burpee     226    9.262295
# 5               thruster     209    8.565574
# 6                boxjump     192    7.868852
# 7                 pushup     190    7.786885
# 8        handstandpushup     180    7.377049
# 9                  squat     179    7.336066
# 10              wallball     176    7.213115
# 11              muscleup     175    7.172131
# 12         overheadsquat     163    6.680328
# 13           doubleunder     155    6.352459
# 14              ghdsitup     135    5.532787
# 15             backsquat     134    5.491803
# 16             ropeclimb     116    4.754098
# 17            frontsquat     114    4.672131
# 18       kettlebellswing     111    4.549180
# 19            squatclean     108    4.426230
# 20                 situp     106    4.344262
# 21             pushpress     105    4.303279
# 22                   dip     102    4.180328
# 23          cleanandjerk      95    3.893443
# 24            powerclean      93    3.811475
# 25                snatch      92    3.770492
# 26          walkinglunge      90    3.688525
# 27                 clean      89    3.647541
# 28             toestobar      89    3.647541
# 29         backextension      70    2.868852
# 30         shoulderpress      68    2.786885
# 31                sprint      68    2.786885
# 32           powersnatch      64    2.622951
# 33              pushjerk      62    2.540984
# 34          sumodeadlift      62    2.540984
# 35            benchpress      61    2.500000
# 36          kneestoelbow      58    2.377049
# 37           squatsnatch      55    2.254098
# 38         handstandwalk      53    2.172131
# 39               pistols      49    2.008197
# 40                 lunge      40    1.639344
# 41          hipextension      36    1.475410
# 42                  swim      27    1.106557
# 43        dumbbellsnatch      23    0.942623
# 44         snatchbalance      22    0.901639
# 45             splitjerk      22    0.901639
# 46          turkishgetup      19    0.778689
# 47                  bike      17    0.696721
# 48           tripleunder      15    0.614754
# 49             sotspress       5    0.204918
# 50  dumbbellcleanandjerk       4    0.163934
# 51           bentoverrow       3    0.122951
# 52     powercleanandjerk       3    0.122951
# 53                stepup       3    0.122951
# 54             broadjump       2    0.081967
# 55           singleunder       2    0.081967
# 56              wallwalk       1    0.040984

# %%
df.plot.bar(x='Movement', y='Percentage', figsize=(12.5,5))

# %%
movements = list(movement_counter.keys())

# %%
fig, ax = plt.subplots(figsize=(20, 20))
G=nx.Graph()

options = {'node_color': 'red',
           'node_size': 100,
           'width': 1,
           'edge_color': '#8c8c8b'}

    # add nodes
for movement in movements:
    G.add_node(movement)

edges = []
for movement in movements:
    for wod in wods:
        if movement in wod:
            for second_movement in wod:
                if movement != second_movement:
                    edges.append((movement, second_movement))
                    
for edge in edges:
    G.add_edge(edge[0], edge[1])
    
pos = nx.spring_layout(G)
nx.draw(G, pos, ax=ax, **options)

for i in pos:
    ax.text(pos[i][0], pos[i][1], i, fontsize=12)

# show graph
plt.show()

# %%
G.nodes('pullup')
# Out:
# NodeDataView({'squat': None, 'pullup': None, 'pushup': None, 'situp': None, 'muscleup': None, 'hipextension': None, 'ghdsitup': None, 'run': None, 'wallball': None, 'thruster': None, 'pushjerk': None, 'broadjump': None, 'walkinglunge': None, 'benchpress': None, 'handstandpushup': None, 'boxjump': None, 'row': None, 'deadlift': None, 'burpee': None, 'doubleunder': None, 'backextension': None, 'overheadsquat': None, 'backsquat': None, 'snatchbalance': None, 'snatch': None, 'kneestoelbow': None, 'kettlebellswing': None, 'pushpress': None, 'squatclean': None, 'toestobar': None, 'shoulderpress': None, 'ropeclimb': None, 'frontsquat': None, 'dip': None, 'splitjerk': None, 'handstandwalk': None, 'sprint': None, 'turkishgetup': None, 'lunge': None, 'bike': None, 'sotspress': None, 'bentoverrow': None, 'swim': None, 'singleunder': None, 'wallwalk': None}, data='pullup')

# %%
G['thruster']
# Out:
# AtlasView({'squat': {}, 'pullup': {}, 'pushup': {}, 'situp': {}, 'muscleup': {}, 'ghdsitup': {}, 'run': {}, 'wallball': {}, 'powerclean': {}, 'row': {}, 'burpee': {}, 'pushjerk': {}, 'boxjump': {}, 'walkinglunge': {}, 'pushpress': {}, 'doubleunder': {}, 'squatclean': {}, 'toestobar': {}, 'ropeclimb': {}, 'deadlift': {}, 'kettlebellswing': {}, 'handstandpushup': {}, 'kneestoelbow': {}, 'clean': {}, 'sumodeadlift': {}, 'sprint': {}, 'powersnatch': {}, 'overheadsquat': {}, 'backsquat': {}, 'dip': {}, 'frontsquat': {}, 'benchpress': {}, 'snatch': {}, 'backextension': {}, 'cleanandjerk': {}, 'splitjerk': {}, 'powercleanandjerk': {}, 'pistols': {}, 'squatsnatch': {}})

# %%
for k in wods_clean:
    if ('thruster' in wods_clean[k]) & ('wallball' in wods_clean[k]):
        print(k, wods_clean[k])
        print(wods_raw[k])
        print()
# Out:
# 2012/12/01 ['burpee', 'backsquat', 'situp', 'kettlebellswing', 'overheadsquat', 'wallball', 'boxjump', 'dip', 'ghdsitup', 'pushup', 'sumodeadlift', 'thruster', 'walkinglunge', 'pullup', 'pushpress', 'clean', 'frontsquat', 'kneestoelbow', 'doubleunder', 'deadlift']
# For time:
# 20 Wall ball shots, 20 pound ball
# 20 Sit-ups
# 20 Box jump, 24" box
# 20 Push-ups
# 135 pound Clean, 20 reps
# 20 Double-unders
# 20 Thrusters, 35 pound dumbbells
# 20 Pull-ups
# 95 pound Overhead squat, 20 reps
# 20 Kettlebell swings, 1.5 poods
# 95 pound Push press, 20 reps
# 20 Dips
# 95 pound Sumo deadlift high pull, 20 reps
# 20 Burpees
# 135 pound Back squat, 20 reps
# 20 GHD sit-ups
# 20 Walking lunge steps
# 135 pound Deadlift, 20 reps
# 20 Knees to elbows
# 135 pound Front squat, 20 repsPost time to comments.
#
# 2013/09/11 ['burpee', 'situp', 'kettlebellswing', 'deadlift', 'boxjump', 'wallball', 'thruster', 'pullup', 'kneestoelbow', 'doubleunder']
# "The Don"For time:
# 66 Deadlifts, 110 pounds
# 66 Box jump, 24 inch box
# 66 Kettlebell swings, 1.5 pood
# 66 Knees to elbows
# 66 Sit-ups
# 66 Pull-ups
# 66 Thrusters, 55 pounds
# 66 Wall ball shots, 20 pound ball
# 66 Burpees
# 66 Double-unders
#
# 2016/05/29 ['thruster', 'pullup', 'wallball', 'row']
# Hildy100-calorie row
# 75 thrusters, 45-lb. barbell
# 50 pull-ups
# 75 wall-ball shots, 20-lb. ball
# 100-calorie row
#
# 2017/01/29 ['thruster', 'wallball', 'toestobar']
# 15-12-9 reps for time of:
# Toes-to-bars
# Wall-ball shots, 20-lb. ball
# 75-lb. thrustersPost time to comments.

# %%
edge_counter = Counter()
for e in edges:
    edge_counter[e] +=1
    
edge_counter.most_common()
# Out:
# [(('pullup', 'run'), 112),
#  (('run', 'pullup'), 112),
#  (('pullup', 'pushup'), 99),
#  (('pushup', 'pullup'), 99),
#  (('squat', 'pushup'), 89),
#  (('pushup', 'squat'), 89),
#  (('squat', 'pullup'), 85),
#  (('pullup', 'squat'), 85),
#  (('pullup', 'thruster'), 78),
#  (('thruster', 'pullup'), 78),
#  (('wallball', 'boxjump'), 73),
#  (('boxjump', 'wallball'), 73),
#  (('pullup', 'burpee'), 72),
#  (('burpee', 'pullup'), 72),
#  (('pullup', 'situp'), 63),
#  (('situp', 'pullup'), 63),
#  (('pullup', 'kettlebellswing'), 61),
#  (('kettlebellswing', 'pullup'), 61),
#  (('pullup', 'handstandpushup'), 58),
#  (('handstandpushup', 'pullup'), 58),
#  (('pullup', 'boxjump'), 55),
#  (('boxjump', 'pullup'), 55),
#  (('boxjump', 'burpee'), 50),
#  (('burpee', 'boxjump'), 50),
#  (('pushup', 'situp'), 47),
#  (('situp', 'pushup'), 47),
#  (('pullup', 'wallball'), 46),
#  (('wallball', 'pullup'), 46),
#  (('run', 'burpee'), 44),
#  (('burpee', 'run'), 44),
#  (('pullup', 'doubleunder'), 42),
#  (('pullup', 'row'), 42),
#  (('handstandpushup', 'deadlift'), 42),
#  (('boxjump', 'kettlebellswing'), 42),
#  (('row', 'pullup'), 42),
#  (('deadlift', 'handstandpushup'), 42),
#  (('doubleunder', 'pullup'), 42),
#  (('kettlebellswing', 'boxjump'), 42),
#  (('wallball', 'row'), 40),
#  (('row', 'wallball'), 40),
#  (('squat', 'run'), 39),
#  (('run', 'squat'), 39),
#  (('squat', 'situp'), 38),
#  (('pushup', 'run'), 38),
#  (('situp', 'squat'), 38),
#  (('run', 'pushup'), 38),
#  (('boxjump', 'row'), 37),
#  (('row', 'boxjump'), 37),
#  (('run', 'deadlift'), 35),
#  (('deadlift', 'run'), 35),
#  (('deadlift', 'burpee'), 35),
#  (('burpee', 'deadlift'), 35),
#  (('pullup', 'deadlift'), 34),
#  (('deadlift', 'pullup'), 34),
#  (('wallball', 'kettlebellswing'), 33),
#  (('boxjump', 'deadlift'), 33),
#  (('deadlift', 'boxjump'), 33),
#  (('kettlebellswing', 'wallball'), 33),
#  (('pullup', 'walkinglunge'), 32),
#  (('pullup', 'kneestoelbow'), 32),
#  (('thruster', 'burpee'), 32),
#  (('walkinglunge', 'pullup'), 32),
#  (('burpee', 'thruster'), 32),
#  (('burpee', 'kettlebellswing'), 32),
#  (('kneestoelbow', 'pullup'), 32),
#  (('kettlebellswing', 'burpee'), 32),
#  (('pullup', 'squatclean'), 30),
#  (('run', 'thruster'), 30),
#  (('thruster', 'run'), 30),
#  (('deadlift', 'shoulderpress'), 30),
#  (('squatclean', 'pullup'), 30),
#  (('shoulderpress', 'deadlift'), 30),
#  (('run', 'boxjump'), 29),
#  (('run', 'kettlebellswing'), 29),
#  (('walkinglunge', 'boxjump'), 29),
#  (('boxjump', 'run'), 29),
#  (('boxjump', 'walkinglunge'), 29),
#  (('boxjump', 'pushpress'), 29),
#  (('deadlift', 'backsquat'), 29),
#  (('backsquat', 'deadlift'), 29),
#  (('kneestoelbow', 'kettlebellswing'), 29),
#  (('kettlebellswing', 'kneestoelbow'), 29),
#  (('kettlebellswing', 'run'), 29),
#  (('pushpress', 'boxjump'), 29),
#  (('pullup', 'backextension'), 28),
#  (('pullup', 'dip'), 28),
#  (('wallball', 'burpee'), 28),
#  (('burpee', 'wallball'), 28),
#  (('backextension', 'kneestoelbow'), 28),
#  (('backextension', 'pullup'), 28),
#  (('kneestoelbow', 'backextension'), 28),
#  (('dip', 'pullup'), 28),
#  (('run', 'wallball'), 27),
#  (('wallball', 'run'), 27),
#  (('boxjump', 'kneestoelbow'), 27),
#  (('backsquat', 'shoulderpress'), 27),
#  (('kneestoelbow', 'boxjump'), 27),
#  (('shoulderpress', 'backsquat'), 27),
#  (('thruster', 'row'), 26),
#  (('walkinglunge', 'burpee'), 26),
#  (('boxjump', 'doubleunder'), 26),
#  (('row', 'thruster'), 26),
#  (('burpee', 'walkinglunge'), 26),
#  (('doubleunder', 'boxjump'), 26),
#  (('pushup', 'row'), 25),
#  (('walkinglunge', 'kneestoelbow'), 25),
#  (('row', 'pushup'), 25),
#  (('row', 'burpee'), 25),
#  (('burpee', 'row'), 25),
#  (('kneestoelbow', 'walkinglunge'), 25),
#  (('situp', 'backextension'), 24),
#  (('muscleup', 'run'), 24),
#  (('muscleup', 'burpee'), 24),
#  (('run', 'muscleup'), 24),
#  (('wallball', 'kneestoelbow'), 24),
#  (('wallball', 'doubleunder'), 24),
#  (('boxjump', 'backextension'), 24),
#  (('burpee', 'muscleup'), 24),
#  (('doubleunder', 'wallball'), 24),
#  (('backextension', 'boxjump'), 24),
#  (('backextension', 'situp'), 24),
#  (('kneestoelbow', 'wallball'), 24),
#  (('pullup', 'pushpress'), 23),
#  (('backextension', 'wallball'), 23),
#  (('pushpress', 'pullup'), 23),
#  (('pullup', 'overheadsquat'), 22),
#  (('run', 'handstandpushup'), 22),
#  (('wallball', 'backextension'), 22),
#  (('handstandpushup', 'run'), 22),
#  (('boxjump', 'sumodeadlift'), 22),
#  (('sumodeadlift', 'boxjump'), 22),
#  (('burpee', 'kneestoelbow'), 22),
#  (('backextension', 'kettlebellswing'), 22),
#  (('overheadsquat', 'pullup'), 22),
#  (('kneestoelbow', 'burpee'), 22),
#  (('kettlebellswing', 'backextension'), 22),
#  (('situp', 'run'), 21),
#  (('muscleup', 'thruster'), 21),
#  (('run', 'row'), 21),
#  (('run', 'situp'), 21),
#  (('run', 'overheadsquat'), 21),
#  (('wallball', 'pushpress'), 21),
#  (('thruster', 'muscleup'), 21),
#  (('handstandpushup', 'kettlebellswing'), 21),
#  (('row', 'run'), 21),
#  (('doubleunder', 'squatclean'), 21),
#  (('overheadsquat', 'run'), 21),
#  (('kettlebellswing', 'handstandpushup'), 21),
#  (('pushpress', 'wallball'), 21),
#  (('squatclean', 'doubleunder'), 21),
#  (('run', 'ropeclimb'), 20),
#  (('wallball', 'walkinglunge'), 20),
#  (('wallball', 'deadlift'), 20),
#  (('walkinglunge', 'wallball'), 20),
#  (('handstandpushup', 'row'), 20),
#  (('boxjump', 'toestobar'), 20),
#  (('row', 'sumodeadlift'), 20),
#  (('row', 'handstandpushup'), 20),
#  (('sumodeadlift', 'row'), 20),
#  (('deadlift', 'wallball'), 20),
#  (('burpee', 'toestobar'), 20),
#  (('toestobar', 'burpee'), 20),
#  (('toestobar', 'boxjump'), 20),
#  (('ropeclimb', 'run'), 20),
#  (('pullup', 'frontsquat'), 19),
#  (('situp', 'doubleunder'), 19),
#  (('muscleup', 'handstandpushup'), 19),
#  (('walkinglunge', 'kettlebellswing'), 19),
#  (('walkinglunge', 'backextension'), 19),
#  (('handstandpushup', 'burpee'), 19),
#  (('handstandpushup', 'muscleup'), 19),
#  (('burpee', 'handstandpushup'), 19),
#  (('doubleunder', 'situp'), 19),
#  (('backextension', 'walkinglunge'), 19),
#  (('kettlebellswing', 'walkinglunge'), 19),
#  (('frontsquat', 'pullup'), 19),
#  (('wallball', 'sumodeadlift'), 18),
#  (('walkinglunge', 'doubleunder'), 18),
#  (('sumodeadlift', 'wallball'), 18),
#  (('burpee', 'doubleunder'), 18),
#  (('burpee', 'squatclean'), 18),
#  (('doubleunder', 'burpee'), 18),
#  (('doubleunder', 'walkinglunge'), 18),
#  (('squatclean', 'burpee'), 18),
#  (('ropeclimb', 'dip'), 18),
#  (('dip', 'ropeclimb'), 18),
#  (('muscleup', 'deadlift'), 17),
#  (('wallball', 'ropeclimb'), 17),
#  (('powerclean', 'deadlift'), 17),
#  (('handstandpushup', 'dip'), 17),
#  (('boxjump', 'squatclean'), 17),
#  (('row', 'pushpress'), 17),
#  (('deadlift', 'doubleunder'), 17),
#  (('deadlift', 'powerclean'), 17),
#  (('deadlift', 'muscleup'), 17),
#  (('burpee', 'pushpress'), 17),
#  (('doubleunder', 'deadlift'), 17),
#  (('doubleunder', 'kettlebellswing'), 17),
#  (('doubleunder', 'overheadsquat'), 17),
#  (('overheadsquat', 'doubleunder'), 17),
#  (('kettlebellswing', 'doubleunder'), 17),
#  (('kettlebellswing', 'pushpress'), 17),
#  (('pushpress', 'burpee'), 17),
#  (('pushpress', 'kettlebellswing'), 17),
#  (('pushpress', 'row'), 17),
#  (('squatclean', 'boxjump'), 17),
#  (('ropeclimb', 'wallball'), 17),
#  (('dip', 'handstandpushup'), 17),
#  (('hipextension', 'ghdsitup'), 16),
#  (('ghdsitup', 'hipextension'), 16),
#  (('ghdsitup', 'overheadsquat'), 16),
#  (('ghdsitup', 'row'), 16),
#  (('run', 'backextension'), 16),
#  (('wallball', 'toestobar'), 16),
#  (('row', 'ghdsitup'), 16),
#  (('deadlift', 'overheadsquat'), 16),
#  (('backextension', 'run'), 16),
#  (('overheadsquat', 'deadlift'), 16),
#  (('overheadsquat', 'ghdsitup'), 16),
#  (('toestobar', 'wallball'), 16),
#  (('squat', 'muscleup'), 15),
#  (('pullup', 'clean'), 15),
#  (('pushup', 'handstandpushup'), 15),
#  (('pushup', 'deadlift'), 15),
#  (('pushup', 'boxjump'), 15),
#  (('situp', 'kettlebellswing'), 15),
#  (('muscleup', 'squat'), 15),
#  (('pushjerk', 'pushpress'), 15),
#  (('walkinglunge', 'ropeclimb'), 15),
#  (('handstandpushup', 'pushup'), 15),
#  (('handstandpushup', 'pistols'), 15),
#  (('boxjump', 'pushup'), 15),
#  (('row', 'toestobar'), 15),
#  (('sumodeadlift', 'pushpress'), 15),
#  (('deadlift', 'pushup'), 15),
#  (('deadlift', 'clean'), 15),
#  (('doubleunder', 'ropeclimb'), 15),
#  (('clean', 'pullup'), 15),
#  (('clean', 'deadlift'), 15),
#  (('clean', 'dip'), 15),
#  (('kneestoelbow', 'pushpress'), 15),
#  (('kettlebellswing', 'situp'), 15),
#  (('pushpress', 'pushjerk'), 15),
#  (('pushpress', 'kneestoelbow'), 15),
#  (('pushpress', 'sumodeadlift'), 15),
#  (('toestobar', 'row'), 15),
#  (('ropeclimb', 'walkinglunge'), 15),
#  (('ropeclimb', 'doubleunder'), 15),
#  (('dip', 'clean'), 15),
#  (('pistols', 'handstandpushup'), 15),
#  (('squat', 'row'), 14),
#  (('pullup', 'benchpress'), 14),
#  (('pullup', 'ghdsitup'), 14),
#  (('muscleup', 'squatclean'), 14),
#  (('ghdsitup', 'run'), 14),
#  (('ghdsitup', 'deadlift'), 14),
#  (('ghdsitup', 'pullup'), 14),
#  (('run', 'ghdsitup'), 14),
#  (('run', 'doubleunder'), 14),
#  (('run', 'squatclean'), 14),
#  (('powerclean', 'burpee'), 14),
#  (('thruster', 'squatclean'), 14),
#  (('thruster', 'ropeclimb'), 14),
#  (('pushjerk', 'deadlift'), 14),
#  (('walkinglunge', 'pushpress'), 14),
#  (('benchpress', 'pullup'), 14),
#  (('boxjump', 'dip'), 14),
#  (('row', 'squat'), 14),
#  (('row', 'doubleunder'), 14),
#  (('deadlift', 'ghdsitup'), 14),
#  (('deadlift', 'pushjerk'), 14),
#  (('burpee', 'powerclean'), 14),
#  (('doubleunder', 'row'), 14),
#  (('doubleunder', 'run'), 14),
#  (('pushpress', 'walkinglunge'), 14),
#  (('squatclean', 'thruster'), 14),
#  (('squatclean', 'muscleup'), 14),
#  (('squatclean', 'run'), 14),
#  (('ropeclimb', 'thruster'), 14),
#  (('dip', 'boxjump'), 14),
#  (('squat', 'deadlift'), 13),
#  (('pullup', 'cleanandjerk'), 13),
#  (('pullup', 'snatch'), 13),
#  (('pullup', 'pistols'), 13),
#  (('pullup', 'powerclean'), 13),
#  (('pushup', 'dip'), 13),
#  (('situp', 'boxjump'), 13),
#  (('ghdsitup', 'backextension'), 13),
#  (('powerclean', 'pullup'), 13),
#  (('thruster', 'doubleunder'), 13),
#  (('thruster', 'toestobar'), 13),
#  (('benchpress', 'clean'), 13),
#  (('boxjump', 'ropeclimb'), 13),
#  (('boxjump', 'situp'), 13),
#  (('boxjump', 'overheadsquat'), 13),
#  (('deadlift', 'squat'), 13),
#  (('cleanandjerk', 'pullup'), 13),
#  (('doubleunder', 'thruster'), 13),
#  (('doubleunder', 'pushpress'), 13),
#  (('doubleunder', 'kneestoelbow'), 13),
#  (('backextension', 'ghdsitup'), 13),
#  (('backextension', 'pushpress'), 13),
#  (('overheadsquat', 'backsquat'), 13),
#  (('overheadsquat', 'boxjump'), 13),
#  (('clean', 'benchpress'), 13),
#  (('backsquat', 'overheadsquat'), 13),
#  (('kneestoelbow', 'doubleunder'), 13),
#  (('snatch', 'pullup'), 13),
#  (('pushpress', 'doubleunder'), 13),
#  (('pushpress', 'backextension'), 13),
#  (('toestobar', 'thruster'), 13),
#  (('ropeclimb', 'boxjump'), 13),
#  (('dip', 'pushup'), 13),
#  (('pistols', 'pullup'), 13),
#  (('squat', 'handstandpushup'), 12),
#  (('situp', 'row'), 12),
#  (('situp', 'walkinglunge'), 12),
#  (('situp', 'ropeclimb'), 12),
#  (('situp', 'kneestoelbow'), 12),
#  (('muscleup', 'squatsnatch'), 12),
#  (('ghdsitup', 'boxjump'), 12),
#  (('run', 'powerclean'), 12),
#  (('wallball', 'handstandpushup'), 12),
#  (('powerclean', 'run'), 12),
#  (('thruster', 'boxjump'), 12),
#  (('thruster', 'deadlift'), 12),
#  (('walkinglunge', 'situp'), 12),
#  (('handstandpushup', 'squat'), 12),
#  (('handstandpushup', 'squatclean'), 12),
#  (('handstandpushup', 'doubleunder'), 12),
#  (('handstandpushup', 'wallball'), 12),
#  (('boxjump', 'thruster'), 12),
#  (('boxjump', 'ghdsitup'), 12),
#  (('row', 'situp'), 12),
#  (('row', 'deadlift'), 12),
#  (('deadlift', 'pushpress'), 12),
#  (('deadlift', 'thruster'), 12),
#  (('deadlift', 'row'), 12),
#  (('burpee', 'backextension'), 12),
#  (('burpee', 'lunge'), 12),
#  (('doubleunder', 'handstandpushup'), 12),
#  (('backextension', 'burpee'), 12),
#  (('overheadsquat', 'frontsquat'), 12),
#  (('backsquat', 'frontsquat'), 12),
#  (('kneestoelbow', 'situp'), 12),
#  (('pushpress', 'deadlift'), 12),
#  (('pushpress', 'shoulderpress'), 12),
#  (('squatclean', 'handstandpushup'), 12),
#  (('shoulderpress', 'pushpress'), 12),
#  (('ropeclimb', 'situp'), 12),
#  (('frontsquat', 'overheadsquat'), 12),
#  (('frontsquat', 'backsquat'), 12),
#  (('squatsnatch', 'muscleup'), 12),
#  (('lunge', 'burpee'), 12),
#  (('squat', 'clean'), 11),
#  (('pullup', 'muscleup'), 11),
#  (('pullup', 'powersnatch'), 11),
#  (('situp', 'burpee'), 11),
#  (('situp', 'dip'), 11),
#  (('muscleup', 'pullup'), 11),
#  (('muscleup', 'wallball'), 11),
#  (('ghdsitup', 'walkinglunge'), 11),
#  (('wallball', 'muscleup'), 11),
#  (('wallball', 'dip'), 11),
#  (('pushjerk', 'shoulderpress'), 11),
#  (('walkinglunge', 'lunge'), 11),
#  (('walkinglunge', 'dip'), 11),
#  (('walkinglunge', 'ghdsitup'), 11),
#  (('benchpress', 'overheadsquat'), 11),
#  (('handstandpushup', 'ropeclimb'), 11),
#  (('deadlift', 'kneestoelbow'), 11),
#  (('deadlift', 'sprint'), 11),
#  (('burpee', 'situp'), 11),
#  (('burpee', 'overheadsquat'), 11),
#  (('doubleunder', 'toestobar'), 11),
#  (('overheadsquat', 'benchpress'), 11),
#  (('overheadsquat', 'clean'), 11),
#  (('overheadsquat', 'burpee'), 11),
#  (('clean', 'overheadsquat'), 11),
#  (('clean', 'squat'), 11),
#  (('powersnatch', 'pullup'), 11),
#  (('kneestoelbow', 'deadlift'), 11),
#  (('toestobar', 'doubleunder'), 11),
#  (('shoulderpress', 'pushjerk'), 11),
#  (('ropeclimb', 'handstandpushup'), 11),
#  (('dip', 'situp'), 11),
#  (('dip', 'wallball'), 11),
#  (('dip', 'walkinglunge'), 11),
#  (('sprint', 'deadlift'), 11),
#  (('lunge', 'walkinglunge'), 11),
#  (('situp', 'wallball'), 10),
#  (('muscleup', 'boxjump'), 10),
#  (('muscleup', 'doubleunder'), 10),
#  (('muscleup', 'toestobar'), 10),
#  (('muscleup', 'ghdsitup'), 10),
#  (('muscleup', 'pistols'), 10),
#  (('muscleup', 'overheadsquat'), 10),
#  (('muscleup', 'row'), 10),
#  (('ghdsitup', 'muscleup'), 10),
#  (('run', 'walkinglunge'), 10),
#  (('run', 'toestobar'), 10),
#  (('run', 'backsquat'), 10),
#  (('wallball', 'situp'), 10),
#  (('powerclean', 'pushjerk'), 10),
#  (('powerclean', 'frontsquat'), 10),
#  (('pushjerk', 'powerclean'), 10),
#  (('walkinglunge', 'run'), 10),
#  (('walkinglunge', 'toestobar'), 10),
#  (('benchpress', 'row'), 10),
#  (('handstandpushup', 'boxjump'), 10),
#  (('boxjump', 'muscleup'), 10),
#  (('boxjump', 'handstandpushup'), 10),
#  (('row', 'benchpress'), 10),
#  (('row', 'muscleup'), 10),
#  (('deadlift', 'toestobar'), 10),
#  (('deadlift', 'frontsquat'), 10),
#  (('burpee', 'sprint'), 10),
#  (('doubleunder', 'backextension'), 10),
#  (('doubleunder', 'muscleup'), 10),
#  (('backextension', 'doubleunder'), 10),
#  (('backextension', 'ropeclimb'), 10),
#  (('overheadsquat', 'dip'), 10),
#  (('overheadsquat', 'muscleup'), 10),
#  (('backsquat', 'run'), 10),
#  (('kneestoelbow', 'ropeclimb'), 10),
#  (('toestobar', 'walkinglunge'), 10),
#  (('toestobar', 'muscleup'), 10),
#  (('toestobar', 'run'), 10),
#  (('toestobar', 'deadlift'), 10),
#  (('ropeclimb', 'backextension'), 10),
#  (('ropeclimb', 'kneestoelbow'), 10),
#  (('frontsquat', 'powerclean'), 10),
#  (('frontsquat', 'deadlift'), 10),
#  (('dip', 'overheadsquat'), 10),
#  (('pistols', 'handstandwalk'), 10),
#  (('pistols', 'muscleup'), 10),
#  (('handstandwalk', 'pistols'), 10),
#  (('sprint', 'burpee'), 10),
#  (('pullup', 'pushjerk'), 9),
#  (('pullup', 'toestobar'), 9),
#  (('pullup', 'ropeclimb'), 9),
#  (('pullup', 'backsquat'), 9),
#  (('pullup', 'hipextension'), 9),
#  (('pushup', 'ropeclimb'), 9),
#  (('muscleup', 'powerclean'), 9),
#  (('hipextension', 'pullup'), 9),
#  (('ghdsitup', 'kettlebellswing'), 9),
#  (('ghdsitup', 'wallball'), 9),
#  (('ghdsitup', 'pushpress'), 9),
#  (('ghdsitup', 'ropeclimb'), 9),
#  (('run', 'frontsquat'), 9),
#  (('wallball', 'clean'), 9),
#  (('wallball', 'powerclean'), 9),
#  (('powerclean', 'muscleup'), 9),
#  (('powerclean', 'wallball'), 9),
#  (('thruster', 'sumodeadlift'), 9),
#  (('pushjerk', 'pullup'), 9),
#  (('walkinglunge', 'squatclean'), 9),
#  (('boxjump', 'clean'), 9),
#  (('row', 'overheadsquat'), 9),
#  (('sumodeadlift', 'thruster'), 9),
#  (('sumodeadlift', 'burpee'), 9),
#  (('burpee', 'sumodeadlift'), 9),
#  (('cleanandjerk', 'ropeclimb'), 9),
#  (('overheadsquat', 'ropeclimb'), 9),
#  (('overheadsquat', 'row'), 9),
#  (('clean', 'boxjump'), 9),
#  (('clean', 'wallball'), 9),
#  (('backsquat', 'pullup'), 9),
#  (('kneestoelbow', 'dip'), 9),
#  (('kettlebellswing', 'ghdsitup'), 9),
#  (('kettlebellswing', 'ropeclimb'), 9),
#  (('kettlebellswing', 'dip'), 9),
#  (('pushpress', 'ghdsitup'), 9),
#  (('squatclean', 'walkinglunge'), 9),
#  (('squatclean', 'toestobar'), 9),
#  (('squatclean', 'ropeclimb'), 9),
#  (('squatclean', 'dip'), 9),
#  (('toestobar', 'pullup'), 9),
#  (('toestobar', 'squatclean'), 9),
#  (('ropeclimb', 'overheadsquat'), 9),
#  (('ropeclimb', 'kettlebellswing'), 9),
#  (('ropeclimb', 'pushup'), 9),
#  (('ropeclimb', 'pullup'), 9),
#  (('ropeclimb', 'squatclean'), 9),
#  (('ropeclimb', 'cleanandjerk'), 9),
#  (('ropeclimb', 'ghdsitup'), 9),
#  (('frontsquat', 'run'), 9),
#  (('dip', 'kettlebellswing'), 9),
#  (('dip', 'kneestoelbow'), 9),
#  (('dip', 'squatclean'), 9),
#  (('squat', 'overheadsquat'), 8),
#  (('squat', 'benchpress'), 8),
#  (('squat', 'walkinglunge'), 8),
#  (('squat', 'dip'), 8),
#  (('squat', 'burpee'), 8),
#  (('squat', 'powerclean'), 8),
#  (('pullup', 'sprint'), 8),
#  (('muscleup', 'kettlebellswing'), 8),
#  (('muscleup', 'clean'), 8),
#  (('muscleup', 'cleanandjerk'), 8),
#  (('ghdsitup', 'toestobar'), 8),
#  (('run', 'cleanandjerk'), 8),
#  (('wallball', 'ghdsitup'), 8),
#  (('powerclean', 'thruster'), 8),
#  (('powerclean', 'squat'), 8),
#  (('thruster', 'powerclean'), 8),
#  (('thruster', 'walkinglunge'), 8),
#  (('thruster', 'kettlebellswing'), 8),
#  (('thruster', 'handstandpushup'), 8),
#  (('pushjerk', 'squatclean'), 8),
#  (('walkinglunge', 'thruster'), 8),
#  (('walkinglunge', 'squat'), 8),
#  (('benchpress', 'squat'), 8),
#  (('handstandpushup', 'thruster'), 8),
#  (('boxjump', 'frontsquat'), 8),
#  (('row', 'ropeclimb'), 8),
#  (('row', 'dip'), 8),
#  (('deadlift', 'kettlebellswing'), 8),
#  (('burpee', 'squat'), 8),
#  (('burpee', 'frontsquat'), 8),
#  (('cleanandjerk', 'run'), 8),
#  (('cleanandjerk', 'muscleup'), 8),
#  (('backextension', 'dip'), 8),
#  (('overheadsquat', 'squat'), 8),
#  (('overheadsquat', 'toestobar'), 8),
#  (('clean', 'muscleup'), 8),
#  (('kettlebellswing', 'deadlift'), 8),
#  (('kettlebellswing', 'thruster'), 8),
#  (('kettlebellswing', 'muscleup'), 8),
#  (('kettlebellswing', 'squatclean'), 8),
#  (('squatclean', 'pushjerk'), 8),
#  (('squatclean', 'kettlebellswing'), 8),
#  (('toestobar', 'overheadsquat'), 8),
#  (('toestobar', 'ghdsitup'), 8),
#  (('ropeclimb', 'row'), 8),
#  (('frontsquat', 'boxjump'), 8),
#  (('frontsquat', 'burpee'), 8),
#  (('dip', 'squat'), 8),
#  (('dip', 'backextension'), 8),
#  (('dip', 'row'), 8),
#  (('sprint', 'pullup'), 8),
#  (('pullup', 'sumodeadlift'), 7),
#  (('pullup', 'lunge'), 7),
#  (('pushup', 'frontsquat'), 7),
#  (('pushup', 'walkinglunge'), 7),
#  (('pushup', 'doubleunder'), 7),
#  (('pushup', 'burpee'), 7),
#  (('situp', 'handstandpushup'), 7),
#  (('situp', 'squatclean'), 7),
#  (('muscleup', 'walkinglunge'), 7),
#  (('muscleup', 'snatch'), 7),
#  (('hipextension', 'run'), 7),
#  (('ghdsitup', 'frontsquat'), 7),
#  (('run', 'hipextension'), 7),
#  (('run', 'snatch'), 7),
#  (('run', 'pushpress'), 7),
#  (('run', 'dip'), 7),
#  (('powerclean', 'handstandpushup'), 7),
#  (('powerclean', 'boxjump'), 7),
#  (('powerclean', 'toestobar'), 7),
#  (('thruster', 'pushpress'), 7),
#  (('thruster', 'kneestoelbow'), 7),
#  (('walkinglunge', 'muscleup'), 7),
#  (('walkinglunge', 'pushup'), 7),
#  (('handstandpushup', 'situp'), 7),
#  (('handstandpushup', 'clean'), 7),
#  (('handstandpushup', 'frontsquat'), 7),
#  (('handstandpushup', 'powerclean'), 7),
#  (('boxjump', 'powerclean'), 7),
#  (('sumodeadlift', 'pullup'), 7),
#  (('deadlift', 'squatclean'), 7),
#  (('burpee', 'backsquat'), 7),
#  (('burpee', 'clean'), 7),
#  (('burpee', 'powersnatch'), 7),
#  (('burpee', 'pushup'), 7),
#  (('burpee', 'snatch'), 7),
#  (('cleanandjerk', 'snatch'), 7),
#  (('doubleunder', 'snatch'), 7),
#  (('doubleunder', 'dip'), 7),
#  (('doubleunder', 'pushup'), 7),
#  (('overheadsquat', 'powersnatch'), 7),
#  (('clean', 'handstandpushup'), 7),
#  (('clean', 'burpee'), 7),
#  (('backsquat', 'burpee'), 7),
#  (('powersnatch', 'overheadsquat'), 7),
#  (('powersnatch', 'burpee'), 7),
#  (('kneestoelbow', 'thruster'), 7),
#  (('snatch', 'cleanandjerk'), 7),
#  (('snatch', 'doubleunder'), 7),
#  (('snatch', 'run'), 7),
#  (('snatch', 'muscleup'), 7),
#  (('snatch', 'burpee'), 7),
#  (('pushpress', 'thruster'), 7),
#  (('pushpress', 'run'), 7),
#  (('pushpress', 'frontsquat'), 7),
#  (('squatclean', 'situp'), 7),
#  (('squatclean', 'deadlift'), 7),
#  (('toestobar', 'powerclean'), 7),
#  (('frontsquat', 'ghdsitup'), 7),
#  (('frontsquat', 'handstandpushup'), 7),
#  (('frontsquat', 'pushup'), 7),
#  (('frontsquat', 'pushpress'), 7),
#  (('dip', 'doubleunder'), 7),
#  (('dip', 'run'), 7),
#  (('lunge', 'pullup'), 7),
#  (('squat', 'backextension'), 6),
#  (('squat', 'pushpress'), 6),
#  (('squat', 'doubleunder'), 6),
#  (('pullup', 'shoulderpress'), 6),
#  (('pushup', 'backextension'), 6),
#  (('pushup', 'swim'), 6),
#  (('pushup', 'powerclean'), 6),
#  (('pushup', 'kneestoelbow'), 6),
#  (('pushup', 'wallball'), 6),
#  (('pushup', 'pushpress'), 6),
#  (('situp', 'overheadsquat'), 6),
#  (('ghdsitup', 'handstandpushup'), 6),
#  (('ghdsitup', 'thruster'), 6),
#  (('ghdsitup', 'burpee'), 6),
#  (('run', 'pistols'), 6),
#  (('wallball', 'pushup'), 6),
#  (('powerclean', 'pushup'), 6),
#  (('thruster', 'pushjerk'), 6),
#  (('thruster', 'ghdsitup'), 6),
#  (('thruster', 'powersnatch'), 6),
#  (('thruster', 'dip'), 6),
#  (('pushjerk', 'thruster'), 6),
#  (('pushjerk', 'doubleunder'), 6),
#  (('walkinglunge', 'handstandwalk'), 6),
#  (('handstandpushup', 'ghdsitup'), 6),
#  (('handstandpushup', 'toestobar'), 6),
#  (('row', 'clean'), 6),
#  (('deadlift', 'dip'), 6),
#  (('deadlift', 'snatch'), 6),
#  (('burpee', 'ghdsitup'), 6),
#  (('doubleunder', 'pushjerk'), 6),
#  (('doubleunder', 'frontsquat'), 6),
#  (('doubleunder', 'squat'), 6),
#  (('doubleunder', 'lunge'), 6),
#  (('doubleunder', 'squatsnatch'), 6),
#  (('backextension', 'overheadsquat'), 6),
#  (('backextension', 'squat'), 6),
#  (('backextension', 'pushup'), 6),
#  (('overheadsquat', 'kneestoelbow'), 6),
#  (('overheadsquat', 'backextension'), 6),
#  (('overheadsquat', 'situp'), 6),
#  (('clean', 'row'), 6),
#  (('clean', 'snatch'), 6),
#  (('backsquat', 'ropeclimb'), 6),
#  (('powersnatch', 'thruster'), 6),
#  (('kneestoelbow', 'overheadsquat'), 6),
#  (('kneestoelbow', 'lunge'), 6),
#  (('kneestoelbow', 'pushup'), 6),
#  (('snatch', 'deadlift'), 6),
#  (('snatch', 'clean'), 6),
#  (('pushpress', 'squat'), 6),
#  (('pushpress', 'lunge'), 6),
#  (('pushpress', 'pushup'), 6),
#  (('squatclean', 'sprint'), 6),
#  (('toestobar', 'handstandpushup'), 6),
#  (('shoulderpress', 'pullup'), 6),
#  (('ropeclimb', 'backsquat'), 6),
#  (('frontsquat', 'doubleunder'), 6),
#  (('dip', 'deadlift'), 6),
#  (('dip', 'thruster'), 6),
#  (('pistols', 'run'), 6),
#  (('squatsnatch', 'doubleunder'), 6),
#  (('handstandwalk', 'walkinglunge'), 6),
#  (('sprint', 'squatclean'), 6),
#  (('lunge', 'pushpress'), 6),
#  (('lunge', 'doubleunder'), 6),
#  (('lunge', 'kneestoelbow'), 6),
#  (('swim', 'pushup'), 6),
#  (('squat', 'ropeclimb'), 5),
#  (('pushup', 'overheadsquat'), 5),
#  (('pushup', 'thruster'), 5),
#  (('pushup', 'ghdsitup'), 5),
#  (('situp', 'deadlift'), 5),
#  (('muscleup', 'handstandwalk'), 5),
#  (('muscleup', 'powersnatch'), 5),
#  (('hipextension', 'handstandwalk'), 5),
#  (('hipextension', 'lunge'), 5),
#  (('ghdsitup', 'doubleunder'), 5),
#  (('ghdsitup', 'backsquat'), 5),
#  (('ghdsitup', 'pushup'), 5),
#  (('ghdsitup', 'pistols'), 5),
#  (('run', 'sumodeadlift'), 5),
#  (('run', 'swim'), 5),
#  (('run', 'bike'), 5),
#  (('run', 'sprint'), 5),
#  (('run', 'lunge'), 5),
#  (('wallball', 'squatclean'), 5),
#  (('powerclean', 'pistols'), 5),
#  (('thruster', 'pushup'), 5),
#  (('thruster', 'sprint'), 5),
#  (('pushjerk', 'frontsquat'), 5),
#  (('walkinglunge', 'handstandpushup'), 5),
#  (('walkinglunge', 'row'), 5),
#  (('benchpress', 'deadlift'), 5),
#  (('handstandpushup', 'overheadsquat'), 5),
#  (('handstandpushup', 'kneestoelbow'), 5),
#  (('handstandpushup', 'walkinglunge'), 5),
#  (('handstandpushup', 'handstandwalk'), 5),
#  (('row', 'backsquat'), 5),
#  (('row', 'walkinglunge'), 5),
#  (('row', 'bike'), 5),
#  (('sumodeadlift', 'run'), 5),
#  (('sumodeadlift', 'dip'), 5),
#  (('deadlift', 'benchpress'), 5),
#  (('deadlift', 'situp'), 5),
#  (('burpee', 'cleanandjerk'), 5),
#  (('cleanandjerk', 'doubleunder'), 5),
#  (('cleanandjerk', 'burpee'), 5),
#  (('cleanandjerk', 'toestobar'), 5),
#  (('doubleunder', 'sprint'), 5),
#  (('doubleunder', 'cleanandjerk'), 5),
#  (('doubleunder', 'powersnatch'), 5),
#  (('doubleunder', 'ghdsitup'), 5),
#  (('backextension', 'squatclean'), 5),
#  (('overheadsquat', 'handstandpushup'), 5),
#  (('overheadsquat', 'pistols'), 5),
#  (('overheadsquat', 'turkishgetup'), 5),
#  (('overheadsquat', 'pushup'), 5),
#  (('overheadsquat', 'pushpress'), 5),
#  (('clean', 'pushpress'), 5),
#  (('backsquat', 'row'), 5),
#  (('backsquat', 'ghdsitup'), 5),
#  (('backsquat', 'pushpress'), 5),
#  (('snatchbalance', 'squatsnatch'), 5),
#  (('powersnatch', 'doubleunder'), 5),
#  (('powersnatch', 'snatch'), 5),
#  (('powersnatch', 'muscleup'), 5),
#  (('kneestoelbow', 'handstandpushup'), 5),
#  (('kneestoelbow', 'squatclean'), 5),
#  (('snatch', 'powersnatch'), 5),
#  (('pushpress', 'clean'), 5),
#  (('pushpress', 'overheadsquat'), 5),
#  (('pushpress', 'backsquat'), 5),
#  (('squatclean', 'backextension'), 5),
#  (('squatclean', 'wallball'), 5),
#  (('squatclean', 'kneestoelbow'), 5),
#  (('squatclean', 'frontsquat'), 5),
#  (('toestobar', 'cleanandjerk'), 5),
#  (('shoulderpress', 'frontsquat'), 5),
#  (('ropeclimb', 'squat'), 5),
#  (('frontsquat', 'squatclean'), 5),
#  (('frontsquat', 'pushjerk'), 5),
#  (('frontsquat', 'shoulderpress'), 5),
#  (('dip', 'sumodeadlift'), 5),
#  (('pistols', 'overheadsquat'), 5),
#  (('pistols', 'powerclean'), 5),
#  (('pistols', 'ghdsitup'), 5),
#  (('squatsnatch', 'snatchbalance'), 5),
#  (('handstandwalk', 'muscleup'), 5),
#  (('handstandwalk', 'hipextension'), 5),
#  (('handstandwalk', 'handstandpushup'), 5),
#  (('handstandwalk', 'lunge'), 5),
#  (('sprint', 'doubleunder'), 5),
#  (('sprint', 'thruster'), 5),
#  (('sprint', 'run'), 5),
#  (('turkishgetup', 'overheadsquat'), 5),
#  (('lunge', 'run'), 5),
#  (('lunge', 'handstandwalk'), 5),
#  (('lunge', 'hipextension'), 5),
#  (('bike', 'run'), 5),
#  (('bike', 'row'), 5),
#  (('swim', 'run'), 5),
#  (('squat', 'backsquat'), 4),
#  (('pullup', 'squatsnatch'), 4),
#  (('pullup', 'dumbbellsnatch'), 4),
#  (('pullup', 'handstandwalk'), 4),
#  (('pushup', 'cleanandjerk'), 4),
#  (('pushup', 'sprint'), 4),
#  (('pushup', 'kettlebellswing'), 4),
#  (('pushup', 'lunge'), 4),
#  (('pushup', 'pistols'), 4),
#  (('situp', 'powerclean'), 4),
#  (('situp', 'ghdsitup'), 4),
#  (('situp', 'thruster'), 4),
#  (('muscleup', 'pushjerk'), 4),
#  (('muscleup', 'pushpress'), 4),
#  (('muscleup', 'dumbbellsnatch'), 4),
#  (('hipextension', 'kneestoelbow'), 4),
#  (('hipextension', 'row'), 4),
#  (('hipextension', 'walkinglunge'), 4),
#  (('ghdsitup', 'kneestoelbow'), 4),
#  (('ghdsitup', 'pushjerk'), 4),
#  (('ghdsitup', 'situp'), 4),
#  (('ghdsitup', 'dip'), 4),
#  (('ghdsitup', 'sumodeadlift'), 4),
#  (('ghdsitup', 'squatclean'), 4),
#  (('run', 'benchpress'), 4),
#  (('run', 'pushjerk'), 4),
#  (('run', 'clean'), 4),
#  (('wallball', 'squatsnatch'), 4),
#  (('wallball', 'thruster'), 4),
#  (('wallball', 'frontsquat'), 4),
#  (('wallball', 'lunge'), 4),
#  (('powerclean', 'situp'), 4),
#  (('powerclean', 'pushpress'), 4),
#  (('thruster', 'clean'), 4),
#  (('thruster', 'overheadsquat'), 4),
#  (('thruster', 'backsquat'), 4),
#  (('thruster', 'situp'), 4),
#  (('thruster', 'wallball'), 4),
#  (('thruster', 'frontsquat'), 4),
#  (('pushjerk', 'boxjump'), 4),
#  (('pushjerk', 'muscleup'), 4),
#  (('pushjerk', 'ghdsitup'), 4),
#  (('pushjerk', 'run'), 4),
#  (('walkinglunge', 'hipextension'), 4),
#  (('benchpress', 'backsquat'), 4),
#  (('benchpress', 'run'), 4),
#  (('handstandpushup', 'sumodeadlift'), 4),
#  (('handstandpushup', 'backsquat'), 4),
#  (('handstandpushup', 'lunge'), 4),
#  (('boxjump', 'pushjerk'), 4),
#  (('boxjump', 'lunge'), 4),
#  (('boxjump', 'pistols'), 4),
#  (('row', 'dumbbellsnatch'), 4),
#  (('row', 'squatsnatch'), 4),
#  (('row', 'kettlebellswing'), 4),
#  (('row', 'backextension'), 4),
#  (('row', 'frontsquat'), 4),
#  (('row', 'turkishgetup'), 4),
#  (('row', 'pistols'), 4),
#  (('row', 'cleanandjerk'), 4),
#  (('row', 'powersnatch'), 4),
#  (('row', 'hipextension'), 4),
#  (('sumodeadlift', 'overheadsquat'), 4),
#  (('sumodeadlift', 'handstandpushup'), 4),
#  (('sumodeadlift', 'ghdsitup'), 4),
#  (('deadlift', 'pistols'), 4),
#  (('deadlift', 'handstandwalk'), 4),
#  (('deadlift', 'ropeclimb'), 4),
#  (('burpee', 'ropeclimb'), 4),
#  (('cleanandjerk', 'pushup'), 4),
#  (('cleanandjerk', 'row'), 4),
#  (('doubleunder', 'clean'), 4),
#  (('doubleunder', 'backsquat'), 4),
#  (('doubleunder', 'dumbbellsnatch'), 4),
#  (('backextension', 'row'), 4),
#  (('overheadsquat', 'snatchbalance'), 4),
#  (('overheadsquat', 'sumodeadlift'), 4),
#  (('overheadsquat', 'thruster'), 4),
#  (('overheadsquat', 'snatch'), 4),
#  (('clean', 'thruster'), 4),
#  (('clean', 'kneestoelbow'), 4),
#  (('clean', 'doubleunder'), 4),
#  (('clean', 'run'), 4),
#  (('backsquat', 'squat'), 4),
#  (('backsquat', 'benchpress'), 4),
#  (('backsquat', 'thruster'), 4),
#  (('backsquat', 'doubleunder'), 4),
#  (('backsquat', 'handstandpushup'), 4),
#  (('snatchbalance', 'overheadsquat'), 4),
#  (('powersnatch', 'row'), 4),
#  (('kneestoelbow', 'ghdsitup'), 4),
#  (('kneestoelbow', 'clean'), 4),
#  (('kneestoelbow', 'handstandwalk'), 4),
#  (('kneestoelbow', 'hipextension'), 4),
#  (('snatch', 'toestobar'), 4),
#  (('snatch', 'overheadsquat'), 4),
#  (('kettlebellswing', 'row'), 4),
#  (('kettlebellswing', 'pushup'), 4),
#  (('kettlebellswing', 'frontsquat'), 4),
#  (('kettlebellswing', 'lunge'), 4),
#  (('pushpress', 'muscleup'), 4),
#  (('pushpress', 'toestobar'), 4),
#  (('pushpress', 'powerclean'), 4),
#  (('squatclean', 'ghdsitup'), 4),
#  (('toestobar', 'pushpress'), 4),
#  (('toestobar', 'ropeclimb'), 4),
#  (('toestobar', 'frontsquat'), 4),
#  (('toestobar', 'snatch'), 4),
#  (('ropeclimb', 'pistols'), 4),
#  (('ropeclimb', 'frontsquat'), 4),
#  (('ropeclimb', 'toestobar'), 4),
#  (('ropeclimb', 'sprint'), 4),
#  (('ropeclimb', 'burpee'), 4),
#  (('ropeclimb', 'deadlift'), 4),
#  (('frontsquat', 'row'), 4),
#  (('frontsquat', 'ropeclimb'), 4),
#  (('frontsquat', 'toestobar'), 4),
#  (('frontsquat', 'kettlebellswing'), 4),
#  (('frontsquat', 'wallball'), 4),
#  (('frontsquat', 'thruster'), 4),
#  (('dip', 'pistols'), 4),
#  (('dip', 'turkishgetup'), 4),
#  (('dip', 'ghdsitup'), 4),
#  (('pistols', 'ropeclimb'), 4),
#  (('pistols', 'dip'), 4),
#  (('pistols', 'deadlift'), 4),
#  (('pistols', 'row'), 4),
#  (('pistols', 'pushup'), 4),
#  (('pistols', 'boxjump'), 4),
#  (('dumbbellsnatch', 'row'), 4),
#  (('dumbbellsnatch', 'pullup'), 4),
#  (('dumbbellsnatch', 'doubleunder'), 4),
#  (('dumbbellsnatch', 'muscleup'), 4),
#  (('squatsnatch', 'row'), 4),
#  (('squatsnatch', 'pullup'), 4),
#  (('squatsnatch', 'wallball'), 4),
#  (('handstandwalk', 'pullup'), 4),
#  (('handstandwalk', 'deadlift'), 4),
#  (('handstandwalk', 'kneestoelbow'), 4),
#  (('sprint', 'pushup'), 4),
#  (('sprint', 'ropeclimb'), 4),
#  (('turkishgetup', 'dip'), 4),
#  (('turkishgetup', 'row'), 4),
#  (('lunge', 'handstandpushup'), 4),
#  (('lunge', 'pushup'), 4),
#  (('lunge', 'kettlebellswing'), 4),
#  (('lunge', 'wallball'), 4),
#  (('lunge', 'boxjump'), 4),
#  (('bike', 'swim'), 4),
#  (('swim', 'bike'), 4),
#  (('squat', 'pistols'), 3),
#  (('squat', 'lunge'), 3),
#  (('squat', 'cleanandjerk'), 3),
#  (('squat', 'handstandwalk'), 3),
#  (('squat', 'boxjump'), 3),
#  (('pullup', 'turkishgetup'), 3),
#  (('pushup', 'muscleup'), 3),
#  (('pushup', 'turkishgetup'), 3),
#  (('pushup', 'snatch'), 3),
#  (('pushup', 'pushjerk'), 3),
#  (('pushup', 'sumodeadlift'), 3),
#  (('pushup', 'clean'), 3),
#  (('situp', 'clean'), 3),
#  (('situp', 'frontsquat'), 3),
#  (('situp', 'toestobar'), 3),
#  (('situp', 'lunge'), 3),
#  (('muscleup', 'pushup'), 3),
#  (('muscleup', 'backextension'), 3),
#  (('muscleup', 'sprint'), 3),
#  (('muscleup', 'ropeclimb'), 3),
#  (('muscleup', 'benchpress'), 3),
#  (('muscleup', 'frontsquat'), 3),
#  (('hipextension', 'boxjump'), 3),
#  (('hipextension', 'handstandpushup'), 3),
#  (('ghdsitup', 'cleanandjerk'), 3),
#  (('ghdsitup', 'clean'), 3),
#  (('ghdsitup', 'handstandwalk'), 3),
#  (('ghdsitup', 'lunge'), 3),
#  (('run', 'squatsnatch'), 3),
#  (('run', 'turkishgetup'), 3),
#  (('run', 'handstandwalk'), 3),
#  (('run', 'powersnatch'), 3),
#  (('wallball', 'cleanandjerk'), 3),
#  (('powerclean', 'clean'), 3),
#  (('powerclean', 'sumodeadlift'), 3),
#  (('powerclean', 'overheadsquat'), 3),
#  (('powerclean', 'backsquat'), 3),
#  (('powerclean', 'doubleunder'), 3),
#  (('thruster', 'benchpress'), 3),
#  (('pushjerk', 'burpee'), 3),
#  (('pushjerk', 'toestobar'), 3),
#  (('pushjerk', 'sumodeadlift'), 3),
#  (('pushjerk', 'pushup'), 3),
#  (('walkinglunge', 'backsquat'), 3),
#  (('walkinglunge', 'clean'), 3),
#  (('walkinglunge', 'deadlift'), 3),
#  (('walkinglunge', 'sprint'), 3),
#  (('walkinglunge', 'overheadsquat'), 3),
#  (('benchpress', 'thruster'), 3),
#  (('benchpress', 'muscleup'), 3),
#  (('handstandpushup', 'pushpress'), 3),
#  (('handstandpushup', 'hipextension'), 3),
#  (('handstandpushup', 'snatch'), 3),
#  (('boxjump', 'handstandwalk'), 3),
#  (('boxjump', 'hipextension'), 3),
#  (('boxjump', 'backsquat'), 3),
#  (('boxjump', 'squat'), 3),
#  (('boxjump', 'sprint'), 3),
#  (('boxjump', 'snatch'), 3),
#  (('row', 'sprint'), 3),
#  (('row', 'snatch'), 3),
#  (('sumodeadlift', 'pushjerk'), 3),
#  (('sumodeadlift', 'clean'), 3),
#  (('sumodeadlift', 'powerclean'), 3),
#  (('sumodeadlift', 'backsquat'), 3),
#  (('sumodeadlift', 'pushup'), 3),
#  (('sumodeadlift', 'frontsquat'), 3),
#  (('deadlift', 'backextension'), 3),
#  (('deadlift', 'walkinglunge'), 3),
#  (('deadlift', 'cleanandjerk'), 3),
#  (('burpee', 'pushjerk'), 3),
#  (('burpee', 'pistols'), 3),
#  (('burpee', 'dumbbellsnatch'), 3),
#  (('cleanandjerk', 'ghdsitup'), 3),
#  (('cleanandjerk', 'squat'), 3),
#  (('cleanandjerk', 'deadlift'), 3),
#  (('cleanandjerk', 'sprint'), 3),
#  (('cleanandjerk', 'wallball'), 3),
#  (('doubleunder', 'pistols'), 3),
#  (('doubleunder', 'powerclean'), 3),
#  (('backextension', 'deadlift'), 3),
#  (('backextension', 'clean'), 3),
#  ...]

# %%
for e in G.edges:
#     if (e[0] == 'thruster') & (e[1] == 'wallball'):
    print(e[0], e[1])
# Out:
# squat pullup
# squat pushup
# squat situp
# squat muscleup
# squat run
# squat benchpress
# squat overheadsquat
# squat handstandpushup
# squat row
# squat ghdsitup
# squat ropeclimb
# squat dip
# squat snatch
# squat backextension
# squat walkinglunge
# squat pushpress
# squat deadlift
# squat handstandwalk
# squat kettlebellswing
# squat toestobar
# squat backsquat
# squat doubleunder
# squat sprint
# squat burpee
# squat lunge
# squat wallball
# squat kneestoelbow
# squat swim
# squat pushjerk
# squat snatchbalance
# squat boxjump
# squat thruster
# squat hipextension
# squat squatclean
# squat bike
# squat frontsquat
# pullup pushup
# pullup situp
# pullup wallball
# pullup thruster
# pullup benchpress
# pullup run
# pullup burpee
# pullup deadlift
# pullup handstandpushup
# pullup pushjerk
# pullup boxjump
# pullup walkinglunge
# pullup pushpress
# pullup muscleup
# pullup doubleunder
# pullup squatclean
# pullup toestobar
# pullup row
# pullup ghdsitup
# pullup frontsquat
# pullup kettlebellswing
# pullup kneestoelbow
# pullup backextension
# pullup sprint
# pullup snatch
# pullup overheadsquat
# pullup dip
# pullup ropeclimb
# pullup handstandwalk
# pullup turkishgetup
# pullup backsquat
# pullup bike
# pullup lunge
# pullup shoulderpress
# pullup hipextension
# pushup situp
# pushup run
# pushup handstandpushup
# pushup row
# pushup deadlift
# pushup boxjump
# pushup dip
# pushup ropeclimb
# pushup overheadsquat
# pushup thruster
# pushup backextension
# pushup swim
# pushup frontsquat
# pushup muscleup
# pushup turkishgetup
# pushup snatch
# pushup pushjerk
# pushup toestobar
# pushup sprint
# pushup walkinglunge
# pushup kneestoelbow
# pushup doubleunder
# pushup burpee
# pushup backsquat
# pushup kettlebellswing
# pushup wallball
# pushup ghdsitup
# pushup pushpress
# pushup lunge
# pushup handstandwalk
# pushup bike
# pushup benchpress
# pushup squatclean
# situp row
# situp burpee
# situp kettlebellswing
# situp handstandpushup
# situp squatclean
# situp doubleunder
# situp backextension
# situp dip
# situp walkinglunge
# situp run
# situp ropeclimb
# situp boxjump
# situp wallball
# situp kneestoelbow
# situp handstandwalk
# situp frontsquat
# situp turkishgetup
# situp overheadsquat
# situp backsquat
# situp deadlift
# situp ghdsitup
# situp thruster
# situp pushpress
# situp toestobar
# situp benchpress
# situp hipextension
# situp lunge
# situp muscleup
# situp snatch
# situp shoulderpress
# muscleup thruster
# muscleup run
# muscleup burpee
# muscleup pushjerk
# muscleup boxjump
# muscleup walkinglunge
# muscleup pushpress
# muscleup doubleunder
# muscleup squatclean
# muscleup toestobar
# muscleup ghdsitup
# muscleup backsquat
# muscleup wallball
# muscleup handstandpushup
# muscleup handstandwalk
# muscleup deadlift
# muscleup snatch
# muscleup overheadsquat
# muscleup kettlebellswing
# muscleup row
# muscleup kneestoelbow
# muscleup backextension
# muscleup sprint
# muscleup ropeclimb
# muscleup benchpress
# muscleup dip
# muscleup hipextension
# muscleup frontsquat
# muscleup lunge
# muscleup turkishgetup
# muscleup singleunder
# hipextension ghdsitup
# hipextension run
# hipextension kneestoelbow
# hipextension handstandwalk
# hipextension boxjump
# hipextension backextension
# hipextension row
# hipextension walkinglunge
# hipextension burpee
# hipextension kettlebellswing
# hipextension wallball
# hipextension pushpress
# hipextension frontsquat
# hipextension benchpress
# hipextension toestobar
# hipextension handstandpushup
# hipextension lunge
# hipextension ropeclimb
# hipextension backsquat
# hipextension shoulderpress
# ghdsitup run
# ghdsitup kneestoelbow
# ghdsitup backextension
# ghdsitup deadlift
# ghdsitup kettlebellswing
# ghdsitup handstandpushup
# ghdsitup boxjump
# ghdsitup thruster
# ghdsitup overheadsquat
# ghdsitup toestobar
# ghdsitup frontsquat
# ghdsitup row
# ghdsitup wallball
# ghdsitup pushjerk
# ghdsitup sprint
# ghdsitup snatch
# ghdsitup pushpress
# ghdsitup ropeclimb
# ghdsitup doubleunder
# ghdsitup backsquat
# ghdsitup burpee
# ghdsitup dip
# ghdsitup walkinglunge
# ghdsitup squatclean
# ghdsitup handstandwalk
# ghdsitup turkishgetup
# ghdsitup lunge
# ghdsitup shoulderpress
# run broadjump
# run walkinglunge
# run thruster
# run wallball
# run boxjump
# run deadlift
# run row
# run ropeclimb
# run handstandpushup
# run kettlebellswing
# run doubleunder
# run squatclean
# run burpee
# run backextension
# run toestobar
# run frontsquat
# run overheadsquat
# run bentoverrow
# run snatch
# run backsquat
# run pushpress
# run turkishgetup
# run kneestoelbow
# run dip
# run swim
# run bike
# run sprint
# run benchpress
# run handstandwalk
# run pushjerk
# run lunge
# wallball boxjump
# wallball row
# wallball deadlift
# wallball ropeclimb
# wallball burpee
# wallball kettlebellswing
# wallball walkinglunge
# wallball pushpress
# wallball kneestoelbow
# wallball backextension
# wallball handstandpushup
# wallball doubleunder
# wallball benchpress
# wallball snatch
# wallball dip
# wallball squatclean
# wallball toestobar
# wallball backsquat
# wallball overheadsquat
# wallball thruster
# wallball frontsquat
# wallball bike
# wallball lunge
# wallball sprint
# wallball pushjerk
# wallball handstandwalk
# thruster row
# thruster burpee
# thruster pushjerk
# thruster boxjump
# thruster walkinglunge
# thruster pushpress
# thruster doubleunder
# thruster squatclean
# thruster toestobar
# thruster ropeclimb
# thruster deadlift
# thruster kettlebellswing
# thruster handstandpushup
# thruster kneestoelbow
# thruster sprint
# thruster snatch
# thruster overheadsquat
# thruster backsquat
# thruster dip
# thruster frontsquat
# thruster benchpress
# thruster backextension
# thruster splitjerk
# pushjerk burpee
# pushjerk boxjump
# pushjerk walkinglunge
# pushjerk pushpress
# pushjerk doubleunder
# pushjerk squatclean
# pushjerk toestobar
# pushjerk deadlift
# pushjerk shoulderpress
# pushjerk frontsquat
# pushjerk backsquat
# pushjerk overheadsquat
# pushjerk row
# pushjerk ropeclimb
# pushjerk handstandpushup
# pushjerk splitjerk
# pushjerk snatch
# broadjump walkinglunge
# walkinglunge burpee
# walkinglunge boxjump
# walkinglunge pushpress
# walkinglunge doubleunder
# walkinglunge squatclean
# walkinglunge toestobar
# walkinglunge kettlebellswing
# walkinglunge kneestoelbow
# walkinglunge backextension
# walkinglunge lunge
# walkinglunge backsquat
# walkinglunge ropeclimb
# walkinglunge dip
# walkinglunge handstandpushup
# walkinglunge deadlift
# walkinglunge row
# walkinglunge sprint
# walkinglunge handstandwalk
# walkinglunge overheadsquat
# walkinglunge frontsquat
# walkinglunge snatch
# walkinglunge shoulderpress
# benchpress overheadsquat
# benchpress row
# benchpress deadlift
# benchpress boxjump
# benchpress backsquat
# benchpress backextension
# benchpress pushpress
# benchpress ropeclimb
# benchpress doubleunder
# benchpress squatclean
# benchpress toestobar
# benchpress snatch
# benchpress dip
# benchpress handstandpushup
# benchpress turkishgetup
# handstandpushup kettlebellswing
# handstandpushup ropeclimb
# handstandpushup overheadsquat
# handstandpushup dip
# handstandpushup sprint
# handstandpushup burpee
# handstandpushup squatclean
# handstandpushup deadlift
# handstandpushup boxjump
# handstandpushup doubleunder
# handstandpushup kneestoelbow
# handstandpushup frontsquat
# handstandpushup snatch
# handstandpushup row
# handstandpushup toestobar
# handstandpushup pushpress
# handstandpushup backextension
# handstandpushup backsquat
# handstandpushup lunge
# handstandpushup handstandwalk
# handstandpushup bike
# boxjump row
# boxjump deadlift
# boxjump burpee
# boxjump pushpress
# boxjump doubleunder
# boxjump squatclean
# boxjump toestobar
# boxjump kettlebellswing
# boxjump kneestoelbow
# boxjump backextension
# boxjump frontsquat
# boxjump ropeclimb
# boxjump dip
# boxjump overheadsquat
# boxjump snatch
# boxjump turkishgetup
# boxjump handstandwalk
# boxjump backsquat
# boxjump lunge
# boxjump sprint
# boxjump bike
# row deadlift
# row snatch
# row burpee
# row doubleunder
# row kettlebellswing
# row ropeclimb
# row backextension
# row frontsquat
# row backsquat
# row toestobar
# row sprint
# row pushpress
# row dip
# row turkishgetup
# row swim
# row bike
# row kneestoelbow
# row overheadsquat
# row squatclean
# row shoulderpress
# row handstandwalk
# row lunge
# deadlift kneestoelbow
# deadlift backextension
# deadlift backsquat
# deadlift shoulderpress
# deadlift overheadsquat
# deadlift doubleunder
# deadlift pushpress
# deadlift burpee
# deadlift kettlebellswing
# deadlift squatclean
# deadlift sprint
# deadlift dip
# deadlift toestobar
# deadlift handstandwalk
# deadlift snatch
# deadlift frontsquat
# deadlift ropeclimb
# deadlift lunge
# deadlift turkishgetup
# deadlift bike
# burpee pushpress
# burpee doubleunder
# burpee squatclean
# burpee toestobar
# burpee kettlebellswing
# burpee kneestoelbow
# burpee backextension
# burpee lunge
# burpee backsquat
# burpee overheadsquat
# burpee bentoverrow
# burpee sprint
# burpee frontsquat
# burpee snatch
# burpee ropeclimb
# burpee dip
# burpee handstandwalk
# burpee bike
# burpee turkishgetup
# doubleunder backextension
# doubleunder pushpress
# doubleunder squatclean
# doubleunder toestobar
# doubleunder kettlebellswing
# doubleunder frontsquat
# doubleunder sprint
# doubleunder snatch
# doubleunder ropeclimb
# doubleunder dip
# doubleunder kneestoelbow
# doubleunder overheadsquat
# doubleunder lunge
# doubleunder backsquat
# doubleunder handstandwalk
# doubleunder shoulderpress
# doubleunder singleunder
# backextension kneestoelbow
# backextension overheadsquat
# backextension kettlebellswing
# backextension pushpress
# backextension ropeclimb
# backextension dip
# backextension squatclean
# backextension turkishgetup
# backextension backsquat
# backextension lunge
# backextension toestobar
# backextension shoulderpress
# overheadsquat snatchbalance
# overheadsquat snatch
# overheadsquat backsquat
# overheadsquat frontsquat
# overheadsquat ropeclimb
# overheadsquat dip
# overheadsquat kneestoelbow
# overheadsquat turkishgetup
# overheadsquat toestobar
# overheadsquat squatclean
# overheadsquat kettlebellswing
# overheadsquat pushpress
# overheadsquat shoulderpress
# overheadsquat handstandwalk
# overheadsquat bike
# overheadsquat lunge
# backsquat shoulderpress
# backsquat frontsquat
# backsquat handstandwalk
# backsquat dip
# backsquat kettlebellswing
# backsquat toestobar
# backsquat lunge
# backsquat ropeclimb
# backsquat pushpress
# backsquat kneestoelbow
# backsquat sprint
# snatchbalance snatch
# snatch squatclean
# snatch kneestoelbow
# snatch dip
# snatch ropeclimb
# snatch handstandwalk
# snatch toestobar
# snatch sprint
# snatch pushpress
# snatch frontsquat
# snatch turkishgetup
# snatch lunge
# kneestoelbow kettlebellswing
# kneestoelbow pushpress
# kneestoelbow ropeclimb
# kneestoelbow dip
# kneestoelbow squatclean
# kneestoelbow handstandwalk
# kneestoelbow lunge
# kneestoelbow frontsquat
# kneestoelbow toestobar
# kneestoelbow wallwalk
# kettlebellswing pushpress
# kettlebellswing ropeclimb
# kettlebellswing toestobar
# kettlebellswing dip
# kettlebellswing squatclean
# kettlebellswing handstandwalk
# kettlebellswing frontsquat
# kettlebellswing bike
# kettlebellswing lunge
# kettlebellswing sprint
# pushpress squatclean
# pushpress toestobar
# pushpress shoulderpress
# pushpress lunge
# pushpress sprint
# pushpress dip
# pushpress frontsquat
# pushpress splitjerk
# pushpress ropeclimb
# squatclean toestobar
# squatclean ropeclimb
# squatclean dip
# squatclean frontsquat
# squatclean sprint
# squatclean swim
# squatclean singleunder
# squatclean splitjerk
# squatclean handstandwalk
# toestobar sprint
# toestobar ropeclimb
# toestobar frontsquat
# toestobar lunge
# toestobar dip
# toestobar handstandwalk
# toestobar bike
# shoulderpress frontsquat
# shoulderpress dip
# shoulderpress lunge
# ropeclimb dip
# ropeclimb frontsquat
# ropeclimb sprint
# ropeclimb handstandwalk
# ropeclimb turkishgetup
# frontsquat handstandwalk
# frontsquat dip
# frontsquat lunge
# frontsquat splitjerk
# dip turkishgetup
# dip lunge
# handstandwalk sotspress
# handstandwalk lunge
# handstandwalk sprint
# handstandwalk bike
# sprint lunge
# sprint swim
# sprint bike
# turkishgetup sotspress
# turkishgetup lunge
# lunge bike
# bike swim
